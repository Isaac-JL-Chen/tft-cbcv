# %% [markdown]
# This is for 1) acquisition, 2) initial spend time series generation.

# %%
### Using Darts package to generate covariates (of course we can do manually)
from darts.utils.timeseries_generation import datetime_attribute_timeseries, holidays_timeseries, linear_timeseries
from darts import TimeSeries, concatenate
from darts.dataprocessing.transformers import Scaler
from darts.utils.missing_values import fill_missing_values
import darts
print('darts version:', darts.__version__)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import shutil

import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

DLNAME='tft_google'
TARGET='acq_initialspend'

## Choosing workspace (which has GPU machine)
DGX=True
Databricks=False
AutoDL=False
Colab=False 
KKlaptop=False
GTX1080=False

## Set working directories 
if GTX1080:
    ### spec: 4x GeForce GTX 1080 Ti
    CURRENT_PATH = '/home/zhaoqi/cbcv'
    READ_DIR = '/home/zhaoqi/cbcv/data/weekly_cohort_sample100_zeromasked'

if DGX:
    ### spec: 8x Tesla V100
    CURRENT_PATH = '/home/jhan405/cbcv/tft_google_ver4/jianlin-tft'
    READ_DIR = f'{CURRENT_PATH}/data/weekly_cohort_data_1000'

if Databricks:
    ### cluster
    pass

if AutoDL:
    CURRENT_PATH = '/root/autodl-tmp/Boston'
    READ_DIR = f'{CURRENT_PATH}/data/weekly_cohort_sample100_zeromasked'


### Set where to save
SAVE_DIR =f'{CURRENT_PATH}/data/preprocessed_data/{DLNAME}/{TARGET}' # where to save prediction results


## Create a new directory if it does not exist
import os
if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)
# Out:
# darts version: 0.20.0

# %%
INPUT_CHUNK_LENGTH = 12

## set date range and time unit
TRAIN_START='2017-01-01' # Q1 2017
TEST_START = '2019-04-01' # Q2 2019
TRAIN_START_INPUTCHUNK=(pd.to_datetime(TRAIN_START) - timedelta(days=7*INPUT_CHUNK_LENGTH)).strftime('%Y-%m-%d')
TRAIN_END=(pd.to_datetime(TEST_START) - timedelta(days=1)).strftime('%Y-%m-%d')
TEST_END='2020-02-29' # Before Covid
TEST_END_EXTEND='2020-05-31' # + additional one quarter (for computational issue)

# %%
### read filelist
import glob
filelist=glob.glob(f'{READ_DIR}/*') # all paths for data files
filelist.sort()

K_LIST = range(len(filelist))
print(K_LIST)
print(filelist[:5])
# Out:
# range(0, 1075)
# ['/home/jhan405/cbcv/tft_google_ver4/data/weekly_cohort_data_1000/1000_jam_city_inc_jam_city_inc_cohort.csv', '/home/jhan405/cbcv/tft_google_ver4/data/weekly_cohort_data_1000/1001_heritage_dairy_heritage_dairy_cohort.csv', '/home/jhan405/cbcv/tft_google_ver4/data/weekly_cohort_data_1000/1002_unitedhealth_optumrx_cohort.csv', '/home/jhan405/cbcv/tft_google_ver4/data/weekly_cohort_data_1000/1003_h_r_block_h_r_diy_cohort.csv', '/home/jhan405/cbcv/tft_google_ver4/data/weekly_cohort_data_1000/1004_bmw_payments_bmw_payments_cohort.csv']

# %%
def read_file(K):
    
    ## choose company
    COMPANY_NAME = os.path.splitext(os.path.split(filelist[K])[1])[0][:-len('_cohort')]
    FILEPATH = os.path.splitext(os.path.split(filelist[K])[1])[0] + '.csv'
    print('K =', K, ', COMPANY_NAME:', COMPANY_NAME)

    ## read company
    COL_NAMES_TO_READ = ['acq_week', # group identifier
                    'week', 'tenure', # time identifier
                #  'spend', # target
                    'N_week_cohort', 'acq_quarter', 'merchant_index', 'merchant'] 

    raw_df = pd.read_csv(f'{READ_DIR}/{FILEPATH}') 
                    # usecols=COL_NAMES_TO_READ)[COL_NAMES_TO_READ]

    ### create initial spend
    raw_df['initial_order'] = raw_df['orders'] - raw_df['rpt_orders']
    raw_df['initial_order_per_cust'] = raw_df['initial_order'] / raw_df['N_week_cohort']
    raw_df['initial_spend'] = raw_df['spend'] - raw_df['rpt_spend']
    raw_df['initial_spend_per_cust'] = raw_df['initial_spend'] / raw_df['N_week_cohort']
    raw_df['initial_aov'] = raw_df['initial_spend'] / raw_df['initial_order']
    
    # ignore initial vs repeat
    raw_df['aov'] = raw_df['spend'] / raw_df['orders']
    raw_df['orders_per_cust'] = raw_df['orders'] / raw_df['N_week_cohort']

    raw_df=raw_df[raw_df['tenure']==0] # pick one obs per each acq_week
    print(raw_df.shape[0], 'rows')
    raw_df.sort_values('acq_week')


    # ## Define main columns: {group, time, value}
    # raw_df.rename(columns={'acq_week': 'time', 
    #                     'N_week_cohort': 'value'}, inplace=True) # single time series (one group)

    ## limit data time range
    df = raw_df[ (raw_df['acq_week']<=TEST_END) & (raw_df['acq_week']>=TRAIN_START_INPUTCHUNK) ]
    df.loc[:,'acq_week'] = pd.to_datetime(df['acq_week'])


    # ### fill missing values
    # import pickle
    # time_acq = pd.read_pickle(f'{CURRENT_PATH}/utils/time_acq_template.pickle')

    # ## write down for data with missingness
    # if df.shape[0] != len(time_acq):
    #     file1 = open(f'{CURRENT_PATH}/misc/acq_data_preprocessing.txt',"w")
    #     file1.write(f'{COMPANY_NAME} has {df.shape[0]} rows. {len(time_acq) - df.shape[0]} rows are missing. \n')
    #     file1.close() #to change file access modes

    # df = pd.merge(time_acq, df, left_on = ['time'], right_index=True, how = 'left')
    # df = df.fillna(method = 'ffill') # propagate non-null values forward
    # df = df.fillna(0) # fill with 0
    
    return df

# %%
def generate_covariates(df):

    actual_one = TimeSeries.from_dataframe(df, 
                                        time_col='acq_week',
                                        value_cols=['N_week_cohort', # prediction target 
                                                    'initial_order', # = N_week_cohort 
                                                    'initial_order_per_cust', # = 1 always
                                                    'initial_spend', # initial_aov * initial order
                                                    'initial_aov', # prediction target
                                                    'orders',
                                                    'orders_per_cust',
                                                    'spend',
                                                    'aov']) # prediction target


    ### generate covariates (for continuous covariates, applying scaler)
    train_scaler = Scaler()

    ## year (numerical)
    year_series = datetime_attribute_timeseries(
        pd.date_range(start=actual_one.start_time(), 
                    end=pd.Timestamp(TEST_END),
                    freq=actual_one.freq_str, 
                    ),
        attribute="year",
        one_hot=False, # consider it as numerical
    )
    year_series = Scaler().fit_transform(year_series) # n_jobs=-1 for large data

    # ## month (categorical)
    # month_series = datetime_attribute_timeseries(
    #     year_series, 
    #     attribute="month", 
    #     one_hot=True # categorical
    # )

    ## week of year (categorical)
    weekofyear_series = datetime_attribute_timeseries(
                year_series, 
                attribute="weekofyear", 
                one_hot=False,
            )

    holiday_series = holidays_timeseries(
        pd.date_range(start=actual_one.start_time(), 
                    end=pd.Timestamp(TEST_END),
                    freq=actual_one.freq_str, 
                    ),
        country_code='US',
        column_name='holidays',
    )

    linear_trend = linear_timeseries(
                start=actual_one.start_time(),
                end=pd.Timestamp(TEST_END),
                freq=actual_one.freq_str, 
                column_name='linear')  

    quadratic_trend=linear_trend*linear_trend

    # covariates = year_series.stack(holiday_series).stack(weekofyear_series)
    covariates = year_series.stack(holiday_series).stack(weekofyear_series).stack(linear_trend).stack(quadratic_trend)
    data_df = actual_one.stack(covariates).pd_dataframe()

    data_df['merchant_index'] = df['merchant_index'].iloc[0]
    data_df['merchant'] = df['merchant'].iloc[0]
    data_df['category'] = df['category'].iloc[0]
    data_df['subcategory'] = df['subcategory'].iloc[0]

    data_df.reset_index(inplace=True)

    # ## column names back
    # data_df.rename(columns={'time': 'acq_week', 
    #                     'value': 'N_week_cohort'}, inplace=True) # single time series (one group)
    
    return data_df

# %%
### for loop
data_df_list = []
for K in K_LIST:
    df = read_file(K)
    
    if (df[df['acq_week']>=TEST_START].shape[0] != 0):
        data_df_list.append(generate_covariates(df))

### combine everything
df_combined = pd.concat(data_df_list).reset_index(drop=True)

# ### for company_0_100.csv, please remove merchant_index=1028, merchant=lyft_bikes_scooters
# indexdrop = df_combined[df_combined['merchant_index'] == 1028].index
# df_combined.drop(indexdrop , inplace=True)

### combine everything
df_combined.to_csv(f'{SAVE_DIR}/company_0_1000.csv')
# Out:
# K = 0 , COMPANY_NAME: 1000_jam_city_inc_jam_city_inc
# 249 rows
# K = 1 , COMPANY_NAME: 1001_heritage_dairy_heritage_dairy
# 312 rows
# K = 2 , COMPANY_NAME: 1002_unitedhealth_optumrx
# 312 rows
# K = 3 , COMPANY_NAME: 1003_h_r_block_h_r_diy
# 312 rows
# K = 4 , COMPANY_NAME: 1004_bmw_payments_bmw_payments
# 312 rows
# K = 5 , COMPANY_NAME: 1005_west_marine_west_marine
# 312 rows
# K = 6 , COMPANY_NAME: 1006_unilever_ben_and_jerries
# 312 rows
# K = 7 , COMPANY_NAME: 1007_albertsons_adjusted_haggen
# 299 rows
# K = 8 , COMPANY_NAME: 1008_albertsons_adjusted_star_market
# 312 rows
# K = 9 , COMPANY_NAME: 1009_marriott_gaylord_hotels
# 312 rows
# K = 10 , COMPANY_NAME: 100_ahold_delhaize_adjusted_giant_landover
# 312 rows
# K = 11 , COMPANY_NAME: 1010_aldo_aldo
# 312 rows
# K = 12 , COMPANY_NAME: 1011_carnival_carnival_cruises
# 312 rows
# K = 13 , COMPANY_NAME: 1012_foodtown_foodtown
# 312 rows
# K = 14 , COMPANY_NAME: 1013_ross_dd_discount
# 312 rows
# K = 15 , COMPANY_NAME: 1014_jane_com_jane_com
# 312 rows
# K = 16 , COMPANY_NAME: 1015_lord_taylor_lord_taylor
# 312 rows
# K = 17 , COMPANY_NAME: 1016_driven_brands_adjusted_take_5_oil_change
# 207 rows
# K = 18 , COMPANY_NAME: 1017_tapestry_adjusted_kate_spade
# 232 rows
# K = 19 , COMPANY_NAME: 1018_rover_rover
# 312 rows
# K = 20 , COMPANY_NAME: 1019_expedia_adjusted_orbitz
# 312 rows
# K = 21 , COMPANY_NAME: 101_costco_adjusted_costco_gas
# 312 rows
# K = 22 , COMPANY_NAME: 1020_nestle_adjusted_ready_refresh
# 312 rows
# K = 23 , COMPANY_NAME: 1021_bartell_drugs_bartell_drugs
# 312 rows
# K = 24 , COMPANY_NAME: 1022_vanguard_vanguard
# 312 rows
# K = 25 , COMPANY_NAME: 1023_juice_plus_juice_plus
# 312 rows
# K = 26 , COMPANY_NAME: 1024_neiman_marcus_adjusted_neiman_marcus
# 312 rows
# K = 27 , COMPANY_NAME: 1025_marriott_springhill_suites
# 312 rows
# K = 28 , COMPANY_NAME: 1026_viasat_viasat
# 312 rows
# K = 29 , COMPANY_NAME: 1027_coachusa_megabus
# 312 rows
# K = 30 , COMPANY_NAME: 1028_lyft_adjusted_lyft_bikes_scooters
# 160 rows
# K = 31 , COMPANY_NAME: 1029_spartannash_d_and_w
# 312 rows
# K = 32 , COMPANY_NAME: 102_shopify_adjusted_shopify_payments
# 312 rows
# K = 33 , COMPANY_NAME: 1030_tidal_tidal
# 312 rows
# K = 34 , COMPANY_NAME: 1031_mbta_mbta
# 312 rows
# K = 35 , COMPANY_NAME: 1032_zynga_adjusted_zynga
# 312 rows
# K = 36 , COMPANY_NAME: 1033_playtika_playtika
# 312 rows
# K = 37 , COMPANY_NAME: 1034_salsarita_salsarita
# 312 rows
# K = 38 , COMPANY_NAME: 1035_tailored_brands_adjusted_josabank
# 312 rows
# K = 39 , COMPANY_NAME: 1036_josabank_adjusted_josabank
# 312 rows
# K = 40 , COMPANY_NAME: 1037_amc_entertainment_adjusted_carmike
# 261 rows
# K = 41 , COMPANY_NAME: 1038_la_colombe_la_colombe
# 312 rows
# K = 42 , COMPANY_NAME: 1039_herbalife_herbalife
# 312 rows
# K = 43 , COMPANY_NAME: 103_restaurant_brands_popeyes
# 312 rows
# K = 44 , COMPANY_NAME: 1040_davids_bridal_davids_bridal
# 312 rows
# K = 45 , COMPANY_NAME: 1041_disney_magic_kingdom
# 312 rows
# K = 46 , COMPANY_NAME: 1042_proactiv_proactiv
# 312 rows
# K = 47 , COMPANY_NAME: 1043_pancheros_pancheros
# 312 rows
# K = 48 , COMPANY_NAME: 1044_bandai_namco_bandai_namco
# 312 rows
# K = 49 , COMPANY_NAME: 1045_rollins_orkin
# 312 rows
# K = 50 , COMPANY_NAME: 1046_freshly_freshly
# 312 rows
# K = 51 , COMPANY_NAME: 1047_electronic_arts_electronic_arts
# 312 rows
# K = 52 , COMPANY_NAME: 1048_orderup_orderup
# 312 rows
# K = 53 , COMPANY_NAME: 1049_signet_zales
# 312 rows
# K = 54 , COMPANY_NAME: 104_planet_fitness_adjusted_planet_fitness
# 312 rows
# K = 55 , COMPANY_NAME: 1050_great_american_brand_aw
# 312 rows
# K = 56 , COMPANY_NAME: 1051_smokey_bones_smokey_bones
# 312 rows
# K = 57 , COMPANY_NAME: 1052_moon_active_moon_active
# 312 rows
# K = 58 , COMPANY_NAME: 1053_wsdot_good_to_go_wsdot_good_to_go
# 312 rows
# K = 59 , COMPANY_NAME: 1054_big_fish_games_big_fish_games
# 312 rows
# K = 60 , COMPANY_NAME: 1055_thrive_market_thrive_market
# 312 rows
# K = 61 , COMPANY_NAME: 1056_sunglass_hut_sunglass_hut
# 312 rows
# K = 62 , COMPANY_NAME: 1057_pieology_pieology
# 312 rows
# K = 63 , COMPANY_NAME: 1058_uno_pizzeria_uno_pizzeria
# 312 rows
# K = 64 , COMPANY_NAME: 1059_goldman_sachs_marcus_by_gs
# 275 rows
# K = 65 , COMPANY_NAME: 105_petsmart_adjusted_petsmart
# 312 rows
# K = 66 , COMPANY_NAME: 1060_collegeboard_collegeboard
# 312 rows
# K = 67 , COMPANY_NAME: 1061_silver_diner_silver_diner
# 312 rows
# K = 68 , COMPANY_NAME: 1062_logans_roadhouse_logans_roadhouse
# 312 rows
# K = 69 , COMPANY_NAME: 1063_ashley_furniture_ashley_furniture
# 312 rows
# K = 70 , COMPANY_NAME: 1064_nationwide_nationwide_pet
# 302 rows
# K = 71 , COMPANY_NAME: 1065_jostens_jostens
# 312 rows
# K = 72 , COMPANY_NAME: 1066_pappadeaux_seafood_pappadeaux_seafood
# 312 rows
# K = 73 , COMPANY_NAME: 1067_texas_roadhouse_bubbas_33
# 312 rows
# K = 74 , COMPANY_NAME: 1068_play_it_again_sports_play_it_again_sports
# 312 rows
# K = 75 , COMPANY_NAME: 1069_coopers_hawk_coopers_hawk
# 312 rows
# K = 76 , COMPANY_NAME: 106_giant_eagle_getgo
# 312 rows
# K = 77 , COMPANY_NAME: 1070_sprint_adjusted_virgin_mobile
# 311 rows
# K = 78 , COMPANY_NAME: 1071_course_hero_course_hero
# 312 rows
# K = 79 , COMPANY_NAME: 1072_uncle_julios_uncle_julios
# 312 rows
# K = 80 , COMPANY_NAME: 1073_noom_noom
# 311 rows
# K = 81 , COMPANY_NAME: 1074_g6_hospitality_motel_6
# 312 rows
# K = 82 , COMPANY_NAME: 1075_chicos_soma
# 312 rows
# K = 83 , COMPANY_NAME: 1076_upstart_com_adjusted_upstart_com
# 312 rows
# K = 84 , COMPANY_NAME: 1077_equifax_equifax
# 312 rows
# K = 85 , COMPANY_NAME: 1078_harrys_harrys
# 312 rows
# K = 86 , COMPANY_NAME: 1079_zoom_zoom
# 312 rows
# K = 87 , COMPANY_NAME: 107_kroger_fuel_adjusted_kroger
# 312 rows
# K = 88 , COMPANY_NAME: 1080_bargain_hunt_bargain_hunt
# 312 rows
# K = 89 , COMPANY_NAME: 1081_curology_curology
# 312 rows
# K = 90 , COMPANY_NAME: 1082_quaker_steak_quaker_steak
# 312 rows
# K = 91 , COMPANY_NAME: 1083_liberty_expedia_holdings_bodybuilding
# 312 rows
# K = 92 , COMPANY_NAME: 1084_yapstone_yapstone
# 259 rows
# K = 93 , COMPANY_NAME: 1085_modells_modells
# 312 rows
# K = 94 , COMPANY_NAME: 1086_grammarly_grammarly
# 312 rows
# K = 95 , COMPANY_NAME: 1087_signet_piercing_pagoda
# 312 rows
# K = 96 , COMPANY_NAME: 1088_wyndham_adjusted_super_8
# 312 rows
# K = 97 , COMPANY_NAME: 1089_lubys_lubys_cafeteria
# 312 rows
# K = 98 , COMPANY_NAME: 108_yum_pizza_hut_pizza_hut
# 312 rows
# K = 99 , COMPANY_NAME: 1090_signet_adjusted_piercing_pagoda
# 312 rows
# K = 100 , COMPANY_NAME: 1091_visionworks_visionworks
# 312 rows
# K = 101 , COMPANY_NAME: 1092_mcgraw_hill_mcgraw_hill
# 312 rows
# K = 102 , COMPANY_NAME: 1093_expressvpn_expressvpn
# 312 rows
# K = 103 , COMPANY_NAME: 1094_foosacklys_foosacklys
# 312 rows
# K = 104 , COMPANY_NAME: 1095_tcgplayer_tcgplayer
# 312 rows
# K = 105 , COMPANY_NAME: 1096_the_joint_the_joint
# 312 rows
# K = 106 , COMPANY_NAME: 1097_hbc_saks
# 312 rows
# K = 107 , COMPANY_NAME: 1098_landrys_seafood_saltgrass
# 312 rows
# K = 108 , COMPANY_NAME: 1099_diamler_ag_mercedes_benz_payments
# 312 rows
# K = 109 , COMPANY_NAME: 109_panda_express_panda_express
# 312 rows
# K = 110 , COMPANY_NAME: 1100_expedia_adjusted_hotwire_com
# 312 rows
# K = 111 , COMPANY_NAME: 110_racetrac_racetrac
# 312 rows
# K = 112 , COMPANY_NAME: 111_t_mobile_adjusted_t_mobile
# 312 rows
# K = 113 , COMPANY_NAME: 112_papa_john_papa_john
# 312 rows
# K = 114 , COMPANY_NAME: 113_grubhub_adjusted_grubhub_seamless
# 312 rows
# K = 115 , COMPANY_NAME: 114_wakefern_shoprite
# 312 rows
# K = 116 , COMPANY_NAME: 115_little_caesars_little_caesars
# 312 rows
# K = 117 , COMPANY_NAME: 116_etsy_inc_hist_seller_fees_etsy_inc_hist_seller_fees
# 312 rows
# K = 118 , COMPANY_NAME: 117_macy_adjusted_macy
# 312 rows
# K = 119 , COMPANY_NAME: 118_royal_farms_royal_farms
# 312 rows
# K = 120 , COMPANY_NAME: 119_wegmans_wegmans
# 312 rows
# K = 121 , COMPANY_NAME: 11_apple_itunes
# 311 rows
# K = 122 , COMPANY_NAME: 120_aramark_aramark
# 312 rows
# K = 123 , COMPANY_NAME: 121_etsy_adjusted_etsy
# 312 rows
# K = 124 , COMPANY_NAME: 122_autozone_autozone
# 312 rows
# K = 125 , COMPANY_NAME: 123_gap_adjusted_old_navy
# 312 rows
# K = 126 , COMPANY_NAME: 124_michaels_adjusted_michaels
# 312 rows
# K = 127 , COMPANY_NAME: 125_tjx_adjusted_marshalls
# 312 rows
# K = 128 , COMPANY_NAME: 126_marmaxx_adjusted_marshalls
# 312 rows
# K = 129 , COMPANY_NAME: 127_amazon_adjusted_kindle
# 312 rows
# K = 130 , COMPANY_NAME: 128_amazon_ex_whole_foods_adjusted_kindle
# 312 rows
# K = 131 , COMPANY_NAME: 129_geico_geico
# 312 rows
# K = 132 , COMPANY_NAME: 12_target_adjusted_target
# 311 rows
# K = 133 , COMPANY_NAME: 130_redbox_redbox
# 312 rows
# K = 134 , COMPANY_NAME: 131_bww_adjusted_bww
# 312 rows
# K = 135 , COMPANY_NAME: 132_caseys_general_store_adjusted_caseys_general_store
# 312 rows
# K = 136 , COMPANY_NAME: 133_state_farm_state_farm
# 312 rows
# K = 137 , COMPANY_NAME: 134_hobby_lobby_hobby_lobby
# 312 rows
# K = 138 , COMPANY_NAME: 135_ross_ross
# 312 rows
# K = 139 , COMPANY_NAME: 136_dicks_dicks
# 312 rows
# K = 140 , COMPANY_NAME: 137_loves_loves
# 312 rows
# K = 141 , COMPANY_NAME: 138_apple_apple_pay_cash
# 301 rows
# K = 142 , COMPANY_NAME: 139_whataburger_whataburger
# 312 rows
# K = 143 , COMPANY_NAME: 13_royal_dutch_shell_shell
# 311 rows
# K = 144 , COMPANY_NAME: 140_amazon_ex_whole_foods_adjusted_audible
# 312 rows
# K = 145 , COMPANY_NAME: 141_amazon_adjusted_audible
# 312 rows
# K = 146 , COMPANY_NAME: 142_sprint_adjusted_sprint
# 312 rows
# K = 147 , COMPANY_NAME: 143_zaxbys_zaxbys
# 312 rows
# K = 148 , COMPANY_NAME: 144_progressive_progressive
# 312 rows
# K = 149 , COMPANY_NAME: 145_jcpenney_jcpenney
# 312 rows
# K = 150 , COMPANY_NAME: 146_alliance_data_comenity
# 312 rows
# K = 151 , COMPANY_NAME: 147_ulta_ulta
# 312 rows
# K = 152 , COMPANY_NAME: 148_barnes_noble_adjusted_barnes_noble
# 312 rows
# K = 153 , COMPANY_NAME: 149_weis_markets_weis_markets
# 312 rows
# K = 154 , COMPANY_NAME: 150_bath_body_works_bath_body_works
# 312 rows
# K = 155 , COMPANY_NAME: 151_carls_jr_hardees
# 312 rows
# K = 156 , COMPANY_NAME: 152_petco_petco
# 312 rows
# K = 157 , COMPANY_NAME: 153_thorntons_thorntons
# 312 rows
# K = 158 , COMPANY_NAME: 154_valve_steam_games
# 312 rows
# K = 159 , COMPANY_NAME: 155_bojangles_bojangles
# 312 rows
# K = 160 , COMPANY_NAME: 156_siriusxm_siriusxm
# 312 rows
# K = 161 , COMPANY_NAME: 157_amc_entertainment_adjusted_amc
# 312 rows
# K = 162 , COMPANY_NAME: 158_five_guys_five_guys
# 312 rows
# K = 163 , COMPANY_NAME: 159_tractor_supply_adjusted_tractor_supply
# 312 rows
# K = 164 , COMPANY_NAME: 15_starbucks_adjusted_starbucks
# 311 rows
# K = 165 , COMPANY_NAME: 160_dineequity_applebee
# 312 rows
# K = 166 , COMPANY_NAME: 161_brinker_chili
# 312 rows
# K = 167 , COMPANY_NAME: 162_advance_auto_adjusted_advance_auto
# 312 rows
# K = 168 , COMPANY_NAME: 163_albertsons_adjusted_albertsons
# 312 rows
# K = 169 , COMPANY_NAME: 164_unemployment_benefits_unemployment_benefits
# 312 rows
# K = 170 , COMPANY_NAME: 165_kwik_trip_kwik_trip
# 312 rows
# K = 171 , COMPANY_NAME: 166_southeastern_grocers_winn_dixie
# 312 rows
# K = 172 , COMPANY_NAME: 167_kroger_adjusted_fred_meyer
# 312 rows
# K = 173 , COMPANY_NAME: 168_dineequity_ihop
# 312 rows
# K = 174 , COMPANY_NAME: 169_robinhood_robinhood
# 312 rows
# K = 175 , COMPANY_NAME: 170_ez_pass_ez_pass
# 312 rows
# K = 176 , COMPANY_NAME: 171_afterpay_afterpay
# 188 rows
# K = 177 , COMPANY_NAME: 172_goodwill_goodwill
# 312 rows
# K = 178 , COMPANY_NAME: 173_disney_disney
# 312 rows
# K = 179 , COMPANY_NAME: 174_bed_bath_adjusted_bed_bath
# 312 rows
# K = 180 , COMPANY_NAME: 175_albertsons_adjusted_jewel_osco
# 312 rows
# K = 181 , COMPANY_NAME: 176_kroger_ex_fuel_adjusted_king_sooper
# 312 rows
# K = 182 , COMPANY_NAME: 177_digit_co_digit_co
# 312 rows
# K = 183 , COMPANY_NAME: 178_kroger_adjusted_king_sooper
# 312 rows
# K = 184 , COMPANY_NAME: 179_ace_hardware_ace_hardware
# 312 rows
# K = 185 , COMPANY_NAME: 180_arco_arco
# 312 rows
# K = 186 , COMPANY_NAME: 181_five_below_five_below
# 312 rows
# K = 187 , COMPANY_NAME: 182_culvers_culvers
# 312 rows
# K = 188 , COMPANY_NAME: 183_oreilly_auto_adjusted_oreilly_auto
# 312 rows
# K = 189 , COMPANY_NAME: 184_jersey_mikes_jersey_mikes
# 312 rows
# K = 190 , COMPANY_NAME: 185_jackinthebox_jackinthebox
# 312 rows
# K = 191 , COMPANY_NAME: 186_experian_experian
# 312 rows
# K = 192 , COMPANY_NAME: 187_cracker_barrel_adjusted_cracker_barrel
# 312 rows
# K = 193 , COMPANY_NAME: 188_darden_adjusted_olive_garden
# 312 rows
# K = 194 , COMPANY_NAME: 189_great_clips_great_clips
# 312 rows
# K = 195 , COMPANY_NAME: 190_couche_tard_adjusted_corner_store
# 234 rows
# K = 196 , COMPANY_NAME: 191_phillips_66_phillips_66
# 312 rows
# K = 197 , COMPANY_NAME: 192_irs_payments_adjusted_irs_payments
# 312 rows
# K = 198 , COMPANY_NAME: 193_instacart_adjusted_instacart_transaction
# 312 rows
# K = 199 , COMPANY_NAME: 194_raising_canes_raising_canes
# 312 rows
# K = 200 , COMPANY_NAME: 195_gamestop_gamestop
# 312 rows
# K = 201 , COMPANY_NAME: 196_kroger_ex_fuel_adjusted_fred_meyer
# 312 rows
# K = 202 , COMPANY_NAME: 197_big_lots_big_lots
# 312 rows
# K = 203 , COMPANY_NAME: 198_regal_adjusted_regal_cinemas
# 312 rows
# K = 204 , COMPANY_NAME: 199_staples_staples
# 312 rows
# K = 205 , COMPANY_NAME: 200_kroger_adjusted_frys
# 312 rows
# K = 206 , COMPANY_NAME: 201_qxh_adjusted_qvc
# 312 rows
# K = 207 , COMPANY_NAME: 202_united_dairy_farmers_united_dairy_farmers
# 312 rows
# K = 208 , COMPANY_NAME: 203_albertsons_adjusted_acme
# 312 rows
# K = 209 , COMPANY_NAME: 204_cookout_cookout
# 312 rows
# K = 210 , COMPANY_NAME: 205_sprouts_sprouts
# 312 rows
# K = 211 , COMPANY_NAME: 206_ups_ups
# 312 rows
# K = 212 , COMPANY_NAME: 207_menards_menards
# 312 rows
# K = 213 , COMPANY_NAME: 208_chewy_adjusted_chewy
# 312 rows
# K = 214 , COMPANY_NAME: 209_waffle_house_waffle_house
# 312 rows
# K = 215 , COMPANY_NAME: 20_square_gpv_adjusted_square
# 311 rows
# K = 216 , COMPANY_NAME: 210_ahold_delhaize_adjusted_stopandshop
# 312 rows
# K = 217 , COMPANY_NAME: 211_hyvee_hyvee
# 312 rows
# K = 218 , COMPANY_NAME: 212_facebook_adjusted_facebook_other
# 312 rows
# K = 219 , COMPANY_NAME: 213_petsmart_adjusted_chewy
# 238 rows
# K = 220 , COMPANY_NAME: 214_qdoba_qdoba
# 312 rows
# K = 221 , COMPANY_NAME: 215_youtube_youtube
# 312 rows
# K = 222 , COMPANY_NAME: 216_tropical_smoothie_tropical_smoothie
# 312 rows
# K = 223 , COMPANY_NAME: 217_ingles_ingles
# 312 rows
# K = 224 , COMPANY_NAME: 218_american_airlines_american_airlines
# 312 rows
# K = 225 , COMPANY_NAME: 219_victorias_secret_victorias_secret
# 312 rows
# K = 226 , COMPANY_NAME: 21_square_square_cash
# 311 rows
# K = 227 , COMPANY_NAME: 220_groupon_adjusted_groupon
# 312 rows
# K = 228 , COMPANY_NAME: 221_olo_com_olo_com
# 312 rows
# K = 229 , COMPANY_NAME: 222_texas_roadhouse_texas_roadhouse
# 312 rows
# K = 230 , COMPANY_NAME: 223_kroger_ex_fuel_adjusted_frys
# 312 rows
# K = 231 , COMPANY_NAME: 224_onlyfans_onlyfans
# 284 rows
# K = 232 , COMPANY_NAME: 225_duke_energy_duke_energy
# 312 rows
# K = 233 , COMPANY_NAME: 226_uber_driver_pay_adjusted_uber_driver_pay
# 312 rows
# K = 234 , COMPANY_NAME: 227_coinbase_coinbase
# 312 rows
# K = 235 , COMPANY_NAME: 228_cinemark_adjusted_cinemark
# 312 rows
# K = 236 , COMPANY_NAME: 22_dunkin_adjusted_dunkin
# 311 rows
# K = 237 , COMPANY_NAME: 230_american_eagle_adjusted_american_eagle
# 312 rows
# K = 238 , COMPANY_NAME: 231_disney_disney_plus
# 162 rows
# K = 239 , COMPANY_NAME: 232_restaurant_brands_tim_hortons
# 312 rows
# K = 240 , COMPANY_NAME: 233_joann_joann
# 312 rows
# K = 241 , COMPANY_NAME: 234_allstate_allstate
# 312 rows
# K = 242 , COMPANY_NAME: 235_auntie_annes_auntie_annes
# 312 rows
# K = 243 , COMPANY_NAME: 236_parkmobile_parkmobile
# 312 rows
# K = 244 , COMPANY_NAME: 237_academy_sports_academy_sports
# 312 rows
# K = 245 , COMPANY_NAME: 238_affirm_affirm
# 312 rows
# K = 246 , COMPANY_NAME: 239_nintendo_nintendo
# 312 rows
# K = 247 , COMPANY_NAME: 23_7_eleven_adjusted_7_eleven
# 311 rows
# K = 248 , COMPANY_NAME: 240_biglari_holdings_steak_shake
# 312 rows
# K = 249 , COMPANY_NAME: 241_tjx_adjusted_home_goods
# 312 rows
# K = 250 , COMPANY_NAME: 242_home_goods_adjusted_home_goods
# 312 rows
# K = 251 , COMPANY_NAME: 243_qrtea_adjusted_qvc
# 207 rows
# K = 252 , COMPANY_NAME: 244_bjs_wholesale_bjs_wholesale
# 312 rows
# K = 253 , COMPANY_NAME: 245_smoothie_king_smoothie_king
# 312 rows
# K = 254 , COMPANY_NAME: 246_restaurant_brands_firehouse_subs
# 312 rows
# K = 255 , COMPANY_NAME: 247_burlington_burlington
# 312 rows
# K = 256 , COMPANY_NAME: 248_adobe_adobe
# 312 rows
# K = 257 , COMPANY_NAME: 249_att_directv
# 312 rows
# K = 258 , COMPANY_NAME: 24_walgreens_walgreens
# 311 rows
# K = 259 , COMPANY_NAME: 250_amazon_music_amazon_music
# 266 rows
# K = 260 , COMPANY_NAME: 251_ymca_ymca
# 312 rows
# K = 261 , COMPANY_NAME: 252_quickchek_quickchek
# 312 rows
# K = 262 , COMPANY_NAME: 253_postmates_adjusted_postmates
# 312 rows
# K = 263 , COMPANY_NAME: 254_kum_and_go_kum_and_go
# 312 rows
# K = 264 , COMPANY_NAME: 255_h_m_h_m
# 312 rows
# K = 265 , COMPANY_NAME: 256_kroger_adjusted_smiths
# 312 rows
# K = 266 , COMPANY_NAME: 257_wish_com_wish_com
# 312 rows
# K = 267 , COMPANY_NAME: 258_moes_southwest_grill_moes_southwest_grill
# 312 rows
# K = 268 , COMPANY_NAME: 259_eg_group_adjusted_turkey_hill
# 192 rows
# K = 269 , COMPANY_NAME: 25_walgreens_adjusted_walgreens
# 311 rows
# K = 270 , COMPANY_NAME: 260_party_city_adjusted_party_city
# 312 rows
# K = 271 , COMPANY_NAME: 261_sally_beauty_sally_beauty
# 312 rows
# K = 272 , COMPANY_NAME: 262_facebook_adjusted_facebook_p2p
# 312 rows
# K = 273 , COMPANY_NAME: 263_xbox_xbox_live_gold
# 312 rows
# K = 274 , COMPANY_NAME: 264_cumberland_farms_cumberland_farms
# 312 rows
# K = 275 , COMPANY_NAME: 265_cox_communications_cox_communications
# 312 rows
# K = 276 , COMPANY_NAME: 266_lvmh_sephora
# 312 rows
# K = 277 , COMPANY_NAME: 267_irs_payments_adjusted_stimulus_payouts
# 88 rows
# K = 278 , COMPANY_NAME: 268_adt_adt
# 312 rows
# K = 279 , COMPANY_NAME: 269_klarna_klarna
# 312 rows
# K = 280 , COMPANY_NAME: 26_uber_adjusted_uber
# 311 rows
# K = 281 , COMPANY_NAME: 270_conoco_conoco
# 312 rows
# K = 282 , COMPANY_NAME: 271_harbor_freight_harbor_freight
# 312 rows
# K = 283 , COMPANY_NAME: 272_ikea_ikea
# 312 rows
# K = 284 , COMPANY_NAME: 273_dennys_dennys
# 312 rows
# K = 285 , COMPANY_NAME: 274_red_robin_red_robin
# 312 rows
# K = 286 , COMPANY_NAME: 275_forever_21_forever_21
# 312 rows
# K = 287 , COMPANY_NAME: 276_kroger_ex_fuel_adjusted_smiths
# 312 rows
# K = 288 , COMPANY_NAME: 277_gnc_adjusted_gnc
# 312 rows
# K = 289 , COMPANY_NAME: 278_activehours_earnin
# 216 rows
# K = 290 , COMPANY_NAME: 279_fedex_fedex
# 312 rows
# K = 291 , COMPANY_NAME: 27_wawa_wawa
# 311 rows
# K = 292 , COMPANY_NAME: 280_stashinvest_stashinvest
# 312 rows
# K = 293 , COMPANY_NAME: 281_nordstrom_segment_adjusted_nordstrom_full_price
# 312 rows
# K = 294 , COMPANY_NAME: 282_airbnb_adjusted_airbnb
# 312 rows
# K = 295 , COMPANY_NAME: 283_in_n_out_burger_in_n_out_burger
# 312 rows
# K = 296 , COMPANY_NAME: 284_fandango_fandango
# 312 rows
# K = 297 , COMPANY_NAME: 285_wingstop_wingstop
# 312 rows
# K = 298 , COMPANY_NAME: 286_mapco_mapco
# 312 rows
# K = 299 , COMPANY_NAME: 287_buc_ees_buc_ees
# 312 rows
# K = 300 , COMPANY_NAME: 288_roku_roku
# 312 rows
# K = 301 , COMPANY_NAME: 289_maverik_maverik
# 312 rows
# K = 302 , COMPANY_NAME: 290_gap_adjusted_gap
# 312 rows
# K = 303 , COMPANY_NAME: 291_delta_airlines_delta_airlines
# 312 rows
# K = 304 , COMPANY_NAME: 292_sport_clips_sport_clips
# 312 rows
# K = 305 , COMPANY_NAME: 293_total_wine_and_more_total_wine_and_more
# 312 rows
# K = 306 , COMPANY_NAME: 294_levelup_levelup
# 312 rows
# K = 307 , COMPANY_NAME: 295_bloomin_brands_outback
# 312 rows
# K = 308 , COMPANY_NAME: 296_united_continental_united_airlines
# 312 rows
# K = 309 , COMPANY_NAME: 297_fresh_market_fresh_market
# 312 rows
# K = 310 , COMPANY_NAME: 298_krispy_kreme_krispy_kreme
# 312 rows
# K = 311 , COMPANY_NAME: 299_southwest_southwest
# 312 rows
# K = 312 , COMPANY_NAME: 300_lowes_food_lowes_food
# 312 rows
# K = 313 , COMPANY_NAME: 301_schnucks_schnucks
# 312 rows
# K = 314 , COMPANY_NAME: 302_amerco_uhaul
# 312 rows
# K = 315 , COMPANY_NAME: 303_enterprise_enterprise
# 312 rows
# K = 316 , COMPANY_NAME: 304_noodles_noodles
# 312 rows
# K = 317 , COMPANY_NAME: 305_office_depot_office_depot
# 312 rows
# K = 318 , COMPANY_NAME: 306_ez_pass_sunpass
# 312 rows
# K = 319 , COMPANY_NAME: 307_save_a_lot_save_a_lot
# 312 rows
# K = 320 , COMPANY_NAME: 308_mcalisters_mcalisters
# 312 rows
# K = 321 , COMPANY_NAME: 309_winco_foods_winco_foods
# 312 rows
# K = 322 , COMPANY_NAME: 310_designer_brands_adjusted_dsw
# 312 rows
# K = 323 , COMPANY_NAME: 311_valero_valero
# 312 rows
# K = 324 , COMPANY_NAME: 312_albertsons_adjusted_vons
# 312 rows
# K = 325 , COMPANY_NAME: 313_piggly_wiggly_piggly_wiggly
# 312 rows
# K = 326 , COMPANY_NAME: 314_gulf_oil_gulf_oil
# 312 rows
# K = 327 , COMPANY_NAME: 315_cheesecake_adjusted_cheesecake
# 312 rows
# K = 328 , COMPANY_NAME: 316_chevron_texaco
# 312 rows
# K = 329 , COMPANY_NAME: 317_sears_sears
# 312 rows
# K = 330 , COMPANY_NAME: 318_petsmart_adjusted_banfield
# 312 rows
# K = 331 , COMPANY_NAME: 319_dillard_adjusted_dillard
# 312 rows
# K = 332 , COMPANY_NAME: 31_speedway_speedway
# 311 rows
# K = 333 , COMPANY_NAME: 320_belk_belk
# 312 rows
# K = 334 , COMPANY_NAME: 321_kroger_adjusted_ralphs
# 312 rows
# K = 335 , COMPANY_NAME: 322_ipsy_ipsy
# 312 rows
# K = 336 , COMPANY_NAME: 323_giant_eagle_market_district
# 312 rows
# K = 337 , COMPANY_NAME: 324_kroger_ex_fuel_adjusted_ralphs
# 312 rows
# K = 338 , COMPANY_NAME: 325_hudson_hudson_news
# 312 rows
# K = 339 , COMPANY_NAME: 326_potbelly_potbelly
# 312 rows
# K = 340 , COMPANY_NAME: 327_patreon_patreon
# 312 rows
# K = 341 , COMPANY_NAME: 328_apple_apple
# 312 rows
# K = 342 , COMPANY_NAME: 329_csc_serviceworks_air_serv
# 312 rows
# K = 343 , COMPANY_NAME: 32_wendys_wendys
# 311 rows
# K = 344 , COMPANY_NAME: 330_unilever_dollar_shave_club
# 312 rows
# K = 345 , COMPANY_NAME: 331_mty_food_group_cold_stone
# 312 rows
# K = 346 , COMPANY_NAME: 332_fidelity_investments_fidelity_investments
# 309 rows
# K = 347 , COMPANY_NAME: 333_nordstrom_segment_adjusted_nordstrom_off_price
# 312 rows
# K = 348 , COMPANY_NAME: 334_cvs_copay_adjusted_cvs
# 312 rows
# K = 349 , COMPANY_NAME: 335_marcos_pizza_marcos_pizza
# 312 rows
# K = 350 , COMPANY_NAME: 336_nike_adjusted_nike
# 251 rows
# K = 351 , COMPANY_NAME: 337_dish_adjusted_dish
# 312 rows
# K = 352 , COMPANY_NAME: 338_poshmark_poshmark
# 312 rows
# K = 353 , COMPANY_NAME: 339_straight_talk_straight_talk
# 312 rows
# K = 354 , COMPANY_NAME: 33_home_depot_adjusted_home_depot
# 311 rows
# K = 355 , COMPANY_NAME: 340_white_castle_white_castle
# 312 rows
# K = 356 , COMPANY_NAME: 341_mta_metrocard
# 312 rows
# K = 357 , COMPANY_NAME: 342_irs_payments_adjusted_child_tax_credits
# 23 rows
# K = 358 , COMPANY_NAME: 343_apple_apple_pay
# 312 rows
# K = 359 , COMPANY_NAME: 344_hello_fresh_adjusted_hello_fresh
# 312 rows
# K = 360 , COMPANY_NAME: 345_amazon_pay_amazon_pay
# 312 rows
# K = 361 , COMPANY_NAME: 346_checkers_checkers
# 312 rows
# K = 362 , COMPANY_NAME: 347_centurylink_centurylink
# 312 rows
# K = 363 , COMPANY_NAME: 348_sears_kmart
# 312 rows
# K = 364 , COMPANY_NAME: 349_t_mobile_adjusted_metropcs
# 312 rows
# K = 365 , COMPANY_NAME: 34_lowes_adjusted_lowes
# 311 rows
# K = 366 , COMPANY_NAME: 350_kroger_adjusted_marianos
# 312 rows
# K = 367 , COMPANY_NAME: 351_lyft_driver_pay_adjusted_lyft_driver_pay
# 312 rows
# K = 368 , COMPANY_NAME: 352_kroger_ex_fuel_adjusted_marianos
# 312 rows
# K = 369 , COMPANY_NAME: 353_kroger_ex_fuel_adjusted_turkey_hill
# 121 rows
# K = 370 , COMPANY_NAME: 354_walmart_adjusted_vudu
# 312 rows
# K = 371 , COMPANY_NAME: 355_kroger_adjusted_turkey_hill
# 121 rows
# K = 372 , COMPANY_NAME: 356_la_fitness_la_fitness
# 312 rows
# K = 373 , COMPANY_NAME: 357_veterans_canteen_veterans_canteen
# 312 rows
# K = 374 , COMPANY_NAME: 358_walmart_all_adjusted_vudu
# 312 rows
# K = 375 , COMPANY_NAME: 359_cigna_express_scripts
# 312 rows
# K = 376 , COMPANY_NAME: 360_twitch_interactive_twitch_interactive
# 312 rows
# K = 377 , COMPANY_NAME: 361_amazon_adjusted_twitch_interactive
# 312 rows
# K = 378 , COMPANY_NAME: 362_amazon_ex_whole_foods_adjusted_twitch_interactive
# 312 rows
# K = 379 , COMPANY_NAME: 363_ahold_delhaize_adjusted_hannaford
# 312 rows
# K = 380 , COMPANY_NAME: 364_activision_blizzard_blizzard_entertainment
# 312 rows
# K = 381 , COMPANY_NAME: 365_carls_jr_carls_jr
# 312 rows
# K = 382 , COMPANY_NAME: 366_virginia_abc_virginia_abc
# 312 rows
# K = 383 , COMPANY_NAME: 367_freddys_freddys
# 312 rows
# K = 384 , COMPANY_NAME: 368_darden_adjusted_longhorn
# 312 rows
# K = 385 , COMPANY_NAME: 369_tgi_fridays_tgi_fridays
# 312 rows
# K = 386 , COMPANY_NAME: 36_dollar_general_dollar_general
# 311 rows
# K = 387 , COMPANY_NAME: 370_bjs_wholesale_bjs_fuel
# 312 rows
# K = 388 , COMPANY_NAME: 371_rei_coop_rei_coop
# 312 rows
# K = 389 , COMPANY_NAME: 372_pet_supplies_plus_pet_supplies_plus
# 312 rows
# K = 390 , COMPANY_NAME: 373_walgreens_copay_adjusted_walgreens
# 312 rows
# K = 391 , COMPANY_NAME: 374_bob_evans_bob_evans
# 312 rows
# K = 392 , COMPANY_NAME: 375_toysrus_toysrus
# 312 rows
# K = 393 , COMPANY_NAME: 376_flutter_entertainment_fanduel
# 312 rows
# K = 394 , COMPANY_NAME: 377_carters_adjusted_carters
# 312 rows
# K = 395 , COMPANY_NAME: 378_charleys_steaks_charleys_steaks
# 312 rows
# K = 396 , COMPANY_NAME: 379_price_chopper_price_chopper
# 312 rows
# K = 397 , COMPANY_NAME: 380_ollies_bargain_ollies_bargain
# 312 rows
# K = 398 , COMPANY_NAME: 381_wayfair_adjusted_wayfair
# 312 rows
# K = 399 , COMPANY_NAME: 382_ny_times_ny_times
# 312 rows
# K = 400 , COMPANY_NAME: 383_eventbrite_eventbrite
# 312 rows
# K = 401 , COMPANY_NAME: 384_kroger_adjusted_pick_n_save
# 312 rows
# K = 402 , COMPANY_NAME: 385_kroger_ex_fuel_adjusted_pick_n_save
# 312 rows
# K = 403 , COMPANY_NAME: 386_live_nation_ticketmaster
# 312 rows
# K = 404 , COMPANY_NAME: 387_couche_tard_adjusted_holiday_station
# 210 rows
# K = 405 , COMPANY_NAME: 388_chegg_adjusted_chegg_services
# 312 rows
# K = 406 , COMPANY_NAME: 389_red_lobster_red_lobster
# 312 rows
# K = 407 , COMPANY_NAME: 38_sheetz_sheetz
# 311 rows
# K = 408 , COMPANY_NAME: 390_childrens_place_childrens_place
# 312 rows
# K = 409 , COMPANY_NAME: 391_kroger_adjusted_dillons
# 312 rows
# K = 410 , COMPANY_NAME: 392_massage_envy_massage_envy
# 312 rows
# K = 411 , COMPANY_NAME: 393_humana_humana
# 312 rows
# K = 412 , COMPANY_NAME: 394_target_adjusted_shipt
# 207 rows
# K = 413 , COMPANY_NAME: 395_golds_gym_golds_gym
# 312 rows
# K = 414 , COMPANY_NAME: 396_dutch_bros_dutch_bros
# 312 rows
# K = 415 , COMPANY_NAME: 397_cabelas_cabelas
# 312 rows
# K = 416 , COMPANY_NAME: 398_dish_adjusted_slingtv
# 312 rows
# K = 417 , COMPANY_NAME: 399_nordstrom_segment_adjusted_nordstrom_payment
# 312 rows
# K = 418 , COMPANY_NAME: 400_wepay_wepay
# 312 rows
# K = 419 , COMPANY_NAME: 401_hallmark_hallmark
# 312 rows
# K = 420 , COMPANY_NAME: 402_childrens_place_adjusted_childrens_place
# 312 rows
# K = 421 , COMPANY_NAME: 403_mod_pizza_mod_pizza
# 312 rows
# K = 422 , COMPANY_NAME: 404_stitch_fix_adjusted_stitch_fix
# 312 rows
# K = 423 , COMPANY_NAME: 405_draftkings_draftkings
# 312 rows
# K = 424 , COMPANY_NAME: 406_aarons_adjusted_progressive_leasing
# 312 rows
# K = 425 , COMPANY_NAME: 407_woodmans_markets_woodmans_markets
# 312 rows
# K = 426 , COMPANY_NAME: 408_kroger_ex_fuel_adjusted_dillons
# 312 rows
# K = 427 , COMPANY_NAME: 409_office_depot_officemax
# 312 rows
# K = 428 , COMPANY_NAME: 410_tdameritrade_tdameritrade
# 312 rows
# K = 429 , COMPANY_NAME: 411_bjri_bjri
# 312 rows
# K = 430 , COMPANY_NAME: 412_vivint_smart_home_vivint_smart_home
# 312 rows
# K = 431 , COMPANY_NAME: 413_frontdoor_adjusted_american_home_shield
# 312 rows
# K = 432 , COMPANY_NAME: 414_supervalu_adjusted_shoppers_food
# 312 rows
# K = 433 , COMPANY_NAME: 415_teachers_pay_teachers_teachers_pay_teachers
# 312 rows
# K = 434 , COMPANY_NAME: 416_vitamin_shoppe_adjusted_vitamin_shoppe
# 312 rows
# K = 435 , COMPANY_NAME: 417_microsoft_microsoft_365
# 312 rows
# K = 436 , COMPANY_NAME: 418_jamba_juice_jamba_juice
# 312 rows
# K = 437 , COMPANY_NAME: 419_hewlett_packard_hewlett_packard
# 312 rows
# K = 438 , COMPANY_NAME: 41_couche_tard_adjusted_circle_k
# 311 rows
# K = 439 , COMPANY_NAME: 420_sezzle_sezzle
# 251 rows
# K = 440 , COMPANY_NAME: 421_banana_republic_adjusted_banana_republic
# 312 rows
# K = 441 , COMPANY_NAME: 422_gap_adjusted_banana_republic
# 312 rows
# K = 442 , COMPANY_NAME: 423_regis_corp_supercuts
# 312 rows
# K = 443 , COMPANY_NAME: 424_shutterfly_adjusted_shutterfly
# 312 rows
# K = 444 , COMPANY_NAME: 425_kingsgroup_kingsgroup
# 312 rows
# K = 445 , COMPANY_NAME: 426_world_market_world_market
# 312 rows
# K = 446 , COMPANY_NAME: 427_mercari_mercari
# 312 rows
# K = 447 , COMPANY_NAME: 428_att_leap
# 312 rows
# K = 448 , COMPANY_NAME: 429_weight_watchers_weight_watchers
# 312 rows
# K = 449 , COMPANY_NAME: 42_restaurant_brands_burger_king
# 311 rows
# K = 450 , COMPANY_NAME: 430_hilton_hilton
# 312 rows
# K = 451 , COMPANY_NAME: 431_marriott_marriott
# 312 rows
# K = 452 , COMPANY_NAME: 432_jasons_deli_jasons_deli
# 312 rows
# K = 453 , COMPANY_NAME: 433_lidl_lidl
# 311 rows
# K = 454 , COMPANY_NAME: 434_portillos_portillos
# 312 rows
# K = 455 , COMPANY_NAME: 435_shein_shein
# 312 rows
# K = 456 , COMPANY_NAME: 436_dave_and_busters_dave_and_busters
# 312 rows
# K = 457 , COMPANY_NAME: 437_lending_club_lending_club
# 312 rows
# K = 458 , COMPANY_NAME: 438_aaa_aaa
# 312 rows
# K = 459 , COMPANY_NAME: 439_flash_foods_flash_foods
# 307 rows
# K = 460 , COMPANY_NAME: 43_sunoco_sunoco
# 311 rows
# K = 461 , COMPANY_NAME: 440_six_flags_adjusted_six_flags
# 312 rows
# K = 462 , COMPANY_NAME: 441_del_taco_del_taco
# 312 rows
# K = 463 , COMPANY_NAME: 442_att_hbo
# 312 rows
# K = 464 , COMPANY_NAME: 443_aetna_aetna
# 312 rows
# K = 465 , COMPANY_NAME: 444_braums_braums
# 312 rows
# K = 466 , COMPANY_NAME: 445_first_watch_first_watch
# 312 rows
# K = 467 , COMPANY_NAME: 446_fiesta_adjusted_taco_cabana
# 295 rows
# K = 468 , COMPANY_NAME: 447_au_bon_pain_au_bon_pain
# 312 rows
# K = 469 , COMPANY_NAME: 448_southeastern_grocers_bi_lo
# 311 rows
# K = 470 , COMPANY_NAME: 449_golden_corral_golden_corral
# 312 rows
# K = 471 , COMPANY_NAME: 44_verizon_verizon
# 311 rows
# K = 472 , COMPANY_NAME: 450_shake_shack_shake_shack
# 312 rows
# K = 473 , COMPANY_NAME: 451_papa_murphy_papa_murphy
# 312 rows
# K = 474 , COMPANY_NAME: 452_intuit_turbotax
# 312 rows
# K = 475 , COMPANY_NAME: 453_hot_topic_hot_topic
# 312 rows
# K = 476 , COMPANY_NAME: 454_footlocker_adjusted_footlocker
# 312 rows
# K = 477 , COMPANY_NAME: 455_at_home_at_home
# 312 rows
# K = 478 , COMPANY_NAME: 456_urban_urban
# 312 rows
# K = 479 , COMPANY_NAME: 457_hooters_hooters
# 312 rows
# K = 480 , COMPANY_NAME: 458_under_armour_under_armour
# 312 rows
# K = 481 , COMPANY_NAME: 459_kynetic_fanatics
# 312 rows
# K = 482 , COMPANY_NAME: 45_walmart_all_adjusted_sams_club
# 311 rows
# K = 483 , COMPANY_NAME: 460_expedia_adjusted_expedia
# 312 rows
# K = 484 , COMPANY_NAME: 461_zip_zip
# 311 rows
# K = 485 , COMPANY_NAME: 462_cabelas_adjusted_cabelas
# 312 rows
# K = 486 , COMPANY_NAME: 463_penn_station_penn_station
# 312 rows
# K = 487 , COMPANY_NAME: 464_lularoe_lularoe
# 312 rows
# K = 488 , COMPANY_NAME: 465_doordash_adjusted_dashpass
# 251 rows
# K = 489 , COMPANY_NAME: 466_gofundme_gofundme
# 311 rows
# K = 490 , COMPANY_NAME: 467_altice_adjusted_altice
# 312 rows
# K = 491 , COMPANY_NAME: 468_google_pay_google_p2p
# 312 rows
# K = 492 , COMPANY_NAME: 469_fas_mart_fas_mart
# 312 rows
# K = 493 , COMPANY_NAME: 46_att_att
# 311 rows
# K = 494 , COMPANY_NAME: 470_bass_pro_shops_adjusted_bass_pro_shops
# 312 rows
# K = 495 , COMPANY_NAME: 471_google_music_google_music
# 311 rows
# K = 496 , COMPANY_NAME: 472_market_basket_market_basket
# 312 rows
# K = 497 , COMPANY_NAME: 473_j_crew_j_crew
# 312 rows
# K = 498 , COMPANY_NAME: 474_bed_bath_adjusted_world_market
# 265 rows
# K = 499 , COMPANY_NAME: 475_blaze_pizza_blaze_pizza
# 312 rows
# K = 500 , COMPANY_NAME: 476_viacomcbs_paramount_plus
# 312 rows
# K = 501 , COMPANY_NAME: 477_anytime_fitness_anytime_fitness
# 312 rows
# K = 502 , COMPANY_NAME: 478_liberty_interactive_zulily
# 312 rows
# K = 503 , COMPANY_NAME: 479_fresh_thyme_fresh_thyme
# 312 rows
# K = 504 , COMPANY_NAME: 47_doordash_adjusted_doordash
# 311 rows
# K = 505 , COMPANY_NAME: 480_qxh_adjusted_hsn
# 312 rows
# K = 506 , COMPANY_NAME: 481_k_va_t_food_city
# 312 rows
# K = 507 , COMPANY_NAME: 482_albertsons_adjusted_tom_thumb_supermarkets
# 312 rows
# K = 508 , COMPANY_NAME: 483_royal_dutch_shell_jiffy_lube
# 312 rows
# K = 509 , COMPANY_NAME: 484_eg_group_adjusted_cumberland_farms
# 113 rows
# K = 510 , COMPANY_NAME: 485_norton_lifelock_adjusted_norton
# 312 rows
# K = 511 , COMPANY_NAME: 486_exelon_comed
# 312 rows
# K = 512 , COMPANY_NAME: 487_mister_car_wash_adjusted_mister_car_wash
# 312 rows
# K = 513 , COMPANY_NAME: 488_alibaba_aliexpress
# 312 rows
# K = 514 , COMPANY_NAME: 489_spirit_airlines_spirit_airlines
# 312 rows
# K = 515 , COMPANY_NAME: 48_chipotle_chipotle
# 311 rows
# K = 516 , COMPANY_NAME: 490_kroger_adjusted_qfc
# 312 rows
# K = 517 , COMPANY_NAME: 491_sherwin_williams_adjusted_sherwin_williams
# 312 rows
# K = 518 , COMPANY_NAME: 492_spencer_spirit_spirit_halloween
# 312 rows
# K = 519 , COMPANY_NAME: 493_stater_bros_stater_bros
# 312 rows
# K = 520 , COMPANY_NAME: 494_eg_group_adjusted_tom_thumb
# 192 rows
# K = 521 , COMPANY_NAME: 495_ruby_tuesday_ruby_tuesday
# 312 rows
# K = 522 , COMPANY_NAME: 496_rue21_rue21
# 312 rows
# K = 523 , COMPANY_NAME: 497_pandora_internet_pandora_internet
# 312 rows
# K = 524 , COMPANY_NAME: 498_kaiser_permanente_kaiser_permanente
# 312 rows
# K = 525 , COMPANY_NAME: 499_valvoline_valvoline_instant_oil_change
# 312 rows
# K = 526 , COMPANY_NAME: 49_costco_adjusted_costco_ex_gas
# 311 rows
# K = 527 , COMPANY_NAME: 500_checkers_rallys
# 312 rows
# K = 528 , COMPANY_NAME: 501_kroger_ex_fuel_adjusted_qfc
# 312 rows
# K = 529 , COMPANY_NAME: 502_beachbody_adjusted_beachbody
# 312 rows
# K = 530 , COMPANY_NAME: 503_payless_shoe_payless_shoe
# 312 rows
# K = 531 , COMPANY_NAME: 504_paypal_adjusted_payin4
# 308 rows
# K = 532 , COMPANY_NAME: 505_caleres_adjusted_famous_footwear
# 312 rows
# K = 533 , COMPANY_NAME: 506_topgolf_topgolf
# 312 rows
# K = 534 , COMPANY_NAME: 507_paypal_ex_venmo_adjusted_payin4
# 308 rows
# K = 535 , COMPANY_NAME: 508_allsups_allsups
# 312 rows
# K = 536 , COMPANY_NAME: 509_express_express
# 312 rows
# K = 537 , COMPANY_NAME: 50_chevron_chevron
# 311 rows
# K = 538 , COMPANY_NAME: 510_nyc_taxi_nyc_taxi
# 312 rows
# K = 539 , COMPANY_NAME: 511_spencer_spirit_spencers
# 312 rows
# K = 540 , COMPANY_NAME: 512_boston_market_boston_market
# 312 rows
# K = 541 , COMPANY_NAME: 513_amazon_adjusted_zappos
# 312 rows
# K = 542 , COMPANY_NAME: 514_peets_coffee_peets_coffee
# 312 rows
# K = 543 , COMPANY_NAME: 515_genesco_adjusted_journeys
# 312 rows
# K = 544 , COMPANY_NAME: 516_amazon_ex_whole_foods_adjusted_zappos
# 312 rows
# K = 545 , COMPANY_NAME: 517_spartannash_family_fare
# 312 rows
# K = 546 , COMPANY_NAME: 518_tuesday_morning_tuesday_morning
# 312 rows
# K = 547 , COMPANY_NAME: 519_schlotzskys_schlotzskys
# 312 rows
# K = 548 , COMPANY_NAME: 51_exxonmobil_exxonmobil
# 311 rows
# K = 549 , COMPANY_NAME: 520_mellow_mushroom_mellow_mushroom
# 312 rows
# K = 550 , COMPANY_NAME: 521_brueggers_brueggers
# 312 rows
# K = 551 , COMPANY_NAME: 522_western_union_western_union
# 312 rows
# K = 552 , COMPANY_NAME: 523_airbnb_host_adjusted_airbnb_host
# 312 rows
# K = 553 , COMPANY_NAME: 524_cigna_cigna
# 312 rows
# K = 554 , COMPANY_NAME: 525_lululemon_adjusted_lululemon
# 312 rows
# K = 555 , COMPANY_NAME: 526_pf_changs_pf_changs
# 312 rows
# K = 556 , COMPANY_NAME: 527_charlotte_russe_charlotte_russe
# 312 rows
# K = 557 , COMPANY_NAME: 528_amtrak_amtrak
# 312 rows
# K = 558 , COMPANY_NAME: 529_scholastic_scholastic
# 312 rows
# K = 559 , COMPANY_NAME: 52_dollar_tree_dollar_tree
# 311 rows
# K = 560 , COMPANY_NAME: 530_rural_king_rural_king
# 312 rows
# K = 561 , COMPANY_NAME: 531_zoes_zoes
# 312 rows
# K = 562 , COMPANY_NAME: 532_lukoil_lukoil
# 312 rows
# K = 563 , COMPANY_NAME: 533_youtubetv_adjusted_upgraded
# 225 rows
# K = 564 , COMPANY_NAME: 534_fashion_nova_fashion_nova
# 312 rows
# K = 565 , COMPANY_NAME: 535_hungry_howies_hungry_howies
# 312 rows
# K = 566 , COMPANY_NAME: 536_frontier_comm_frontier_comm
# 312 rows
# K = 567 , COMPANY_NAME: 537_adidas_adidas
# 312 rows
# K = 568 , COMPANY_NAME: 538_sprint_adjusted_boost_mobile
# 236 rows
# K = 569 , COMPANY_NAME: 539_chicago_transit_authority_chicago_transit_authority
# 312 rows
# K = 570 , COMPANY_NAME: 53_dollar_tree_ex_family_dollar_adjusted_dollar_tree
# 311 rows
# K = 571 , COMPANY_NAME: 540_pacific_gas_and_electric_pacific_gas_and_electric
# 312 rows
# K = 572 , COMPANY_NAME: 541_tops_tops
# 312 rows
# K = 573 , COMPANY_NAME: 542_true_value_true_value
# 312 rows
# K = 574 , COMPANY_NAME: 543_specs_liquor_specs_liquor
# 312 rows
# K = 575 , COMPANY_NAME: 544_pacific_sunwear_pacific_sunwear
# 312 rows
# K = 576 , COMPANY_NAME: 545_hilton_hampton_inn
# 312 rows
# K = 577 , COMPANY_NAME: 546_heb_heb_to_you
# 312 rows
# K = 578 , COMPANY_NAME: 547_albertsons_adjusted_shaws
# 312 rows
# K = 579 , COMPANY_NAME: 548_cec_entertainment_adjusted_chuck_e_cheese
# 312 rows
# K = 580 , COMPANY_NAME: 549_grocery_outlet_grocery_outlet
# 312 rows
# K = 581 , COMPANY_NAME: 54_microsoft_microsoft
# 311 rows
# K = 582 , COMPANY_NAME: 550_jets_pizza_jets_pizza
# 312 rows
# K = 583 , COMPANY_NAME: 551_vf_corp_adjusted_vans
# 312 rows
# K = 584 , COMPANY_NAME: 552_godaddy_godaddy
# 312 rows
# K = 585 , COMPANY_NAME: 553_chuys_chuys
# 312 rows
# K = 586 , COMPANY_NAME: 554_washington_metro_washington_metro
# 312 rows
# K = 587 , COMPANY_NAME: 555_bass_pro_shops_adjusted_cabelas
# 221 rows
# K = 588 , COMPANY_NAME: 556_brookshires_brookshires
# 312 rows
# K = 589 , COMPANY_NAME: 557_murphy_adjusted_quickchek
# 47 rows
# K = 590 , COMPANY_NAME: 558_smashburger_smashburger
# 312 rows
# K = 591 , COMPANY_NAME: 559_gopuff_gopuff
# 312 rows
# K = 592 , COMPANY_NAME: 55_ahold_delhaize_adjusted_food_lion
# 311 rows
# K = 593 , COMPANY_NAME: 560_walgreens_duane_reade
# 312 rows
# K = 594 , COMPANY_NAME: 561_exelon_bge
# 312 rows
# K = 595 , COMPANY_NAME: 562_niantic_niantic
# 312 rows
# K = 596 , COMPANY_NAME: 563_walgreens_adjusted_duane_reade
# 312 rows
# K = 597 , COMPANY_NAME: 564_churchs_chicken_churchs_chicken
# 312 rows
# K = 598 , COMPANY_NAME: 565_mission_bbq_mission_bbq
# 312 rows
# K = 599 , COMPANY_NAME: 566_krispy_kreme_insomnia_cookies
# 312 rows
# K = 600 , COMPANY_NAME: 567_frontier_airlines_frontier_airlines
# 312 rows
# K = 601 , COMPANY_NAME: 568_amazon_adjusted_ring_com
# 193 rows
# K = 602 , COMPANY_NAME: 569_amazon_ex_whole_foods_adjusted_ring_com
# 193 rows
# K = 603 , COMPANY_NAME: 56_panera_bread_panera_bread
# 311 rows
# K = 604 , COMPANY_NAME: 570_cinnabon_cinnabon
# 312 rows
# K = 605 , COMPANY_NAME: 571_captain_ds_captain_ds
# 312 rows
# K = 606 , COMPANY_NAME: 572_abercrombie_hollister
# 312 rows
# K = 607 , COMPANY_NAME: 573_exelon_peco
# 312 rows
# K = 608 , COMPANY_NAME: 574_xoom_xoom
# 312 rows
# K = 609 , COMPANY_NAME: 575_shipt_adjusted_shipt_order
# 312 rows
# K = 610 , COMPANY_NAME: 576_ascena_adjusted_loft
# 312 rows
# K = 611 , COMPANY_NAME: 577_ascena_premium_group_adjusted_loft
# 312 rows
# K = 612 , COMPANY_NAME: 578_qrtea_adjusted_hsn
# 207 rows
# K = 613 , COMPANY_NAME: 579_ann_taylor_loft
# 312 rows
# K = 614 , COMPANY_NAME: 57_heb_heb
# 311 rows
# K = 615 , COMPANY_NAME: 580_lifetouch_lifetouch
# 312 rows
# K = 616 , COMPANY_NAME: 581_claires_claires
# 312 rows
# K = 617 , COMPANY_NAME: 582_cava_grill_cava_grill
# 312 rows
# K = 618 , COMPANY_NAME: 583_sbarro_sbarro
# 312 rows
# K = 619 , COMPANY_NAME: 584_shoe_carnival_adjusted_shoe_carnival
# 312 rows
# K = 620 , COMPANY_NAME: 585_raleys_raleys
# 312 rows
# K = 621 , COMPANY_NAME: 586_tencent_supercell
# 312 rows
# K = 622 , COMPANY_NAME: 587_urban_anthropologie
# 312 rows
# K = 623 , COMPANY_NAME: 588_anthro_group_anthropologie
# 312 rows
# K = 624 , COMPANY_NAME: 589_francesca_francesca
# 312 rows
# K = 625 , COMPANY_NAME: 58_safeway_adjusted_safeway
# 311 rows
# K = 626 , COMPANY_NAME: 590_marcus_theaters_marcus_theaters
# 312 rows
# K = 627 , COMPANY_NAME: 591_caribou_coffee_caribou_coffee
# 312 rows
# K = 628 , COMPANY_NAME: 592_carmax_carmax
# 312 rows
# K = 629 , COMPANY_NAME: 593_dropbox_dropbox
# 312 rows
# K = 630 , COMPANY_NAME: 594_crunch_crunch
# 312 rows
# K = 631 , COMPANY_NAME: 595_fazolis_fazolis
# 312 rows
# K = 632 , COMPANY_NAME: 596_finish_line_finish_line
# 312 rows
# K = 633 , COMPANY_NAME: 597_qrtea_adjusted_zulily
# 207 rows
# K = 634 , COMPANY_NAME: 598_booksamillion_booksamillion
# 312 rows
# K = 635 , COMPANY_NAME: 599_pep_boys_pep_boys
# 312 rows
# K = 636 , COMPANY_NAME: 600_darden_adjusted_cheddars
# 243 rows
# K = 637 , COMPANY_NAME: 601_kirklands_kirklands
# 312 rows
# K = 638 , COMPANY_NAME: 602_aeropostale_aeropostale
# 312 rows
# K = 639 , COMPANY_NAME: 603_blue_apron_blue_apron
# 312 rows
# K = 640 , COMPANY_NAME: 604_24_hour_fitness_24_hour_fitness
# 312 rows
# K = 641 , COMPANY_NAME: 605_expedia_adjusted_hotels_com
# 312 rows
# K = 642 , COMPANY_NAME: 606_unitedhealth_unitedhealth
# 312 rows
# K = 643 , COMPANY_NAME: 607_betterment_betterment
# 312 rows
# K = 644 , COMPANY_NAME: 608_roblox_roblox
# 312 rows
# K = 645 , COMPANY_NAME: 609_european_wax_european_wax
# 312 rows
# K = 646 , COMPANY_NAME: 60_lyft_adjusted_lyft
# 311 rows
# K = 647 , COMPANY_NAME: 610_which_wich_which_wich
# 312 rows
# K = 648 , COMPANY_NAME: 611_salvation_army_salvation_army
# 312 rows
# K = 649 , COMPANY_NAME: 612_rent_a_center_adjusted_rent_a_center
# 312 rows
# K = 650 , COMPANY_NAME: 613_kroger_adjusted_tom_thumb
# 121 rows
# K = 651 , COMPANY_NAME: 614_ac_moore_ac_moore
# 305 rows
# K = 652 , COMPANY_NAME: 615_kroger_ex_fuel_adjusted_tom_thumb
# 121 rows
# K = 653 , COMPANY_NAME: 616_paypal_ex_venmo_adjusted_bill_me_later
# 312 rows
# K = 654 , COMPANY_NAME: 617_sweetgreen_sweetgreen
# 312 rows
# K = 655 , COMPANY_NAME: 618_rainbow_shop_rainbow_shop
# 312 rows
# K = 656 , COMPANY_NAME: 619_booking_holdings_priceline
# 312 rows
# K = 657 , COMPANY_NAME: 61_albertsons_adjusted_safeway
# 311 rows
# K = 658 , COMPANY_NAME: 620_att_crunchyroll
# 312 rows
# K = 659 , COMPANY_NAME: 621_kroger_fuel_adjusted_fred_meyer
# 312 rows
# K = 660 , COMPANY_NAME: 622_ll_bean_ll_bean
# 312 rows
# K = 661 , COMPANY_NAME: 623_shipt_adjusted_shipt_tips_fees_adj
# 312 rows
# K = 662 , COMPANY_NAME: 624_csc_serviceworks_coinmach
# 312 rows
# K = 663 , COMPANY_NAME: 625_gpc_napa
# 312 rows
# K = 664 , COMPANY_NAME: 626_firestone_firestone
# 312 rows
# K = 665 , COMPANY_NAME: 627_kroger_adjusted_food_4_less
# 312 rows
# K = 666 , COMPANY_NAME: 628_lime_lime
# 306 rows
# K = 667 , COMPANY_NAME: 629_buckys_convenience_stores_buckys_convenience_stores
# 312 rows
# K = 668 , COMPANY_NAME: 62_quiktrip_quiktrip
# 311 rows
# K = 669 , COMPANY_NAME: 630_fiesta_adjusted_pollo_tropical
# 312 rows
# K = 670 , COMPANY_NAME: 631_albertsons_adjusted_randalls
# 312 rows
# K = 671 , COMPANY_NAME: 632_kroger_fuel_adjusted_frys
# 312 rows
# K = 672 , COMPANY_NAME: 633_alaska_airlines_alaska_airlines
# 312 rows
# K = 673 , COMPANY_NAME: 634_public_storage_public_storage
# 312 rows
# K = 674 , COMPANY_NAME: 635_corner_bakery_corner_bakery
# 312 rows
# K = 675 , COMPANY_NAME: 636_natural_grocers_natural_grocers
# 312 rows
# K = 676 , COMPANY_NAME: 637_marriott_courtyard
# 312 rows
# K = 677 , COMPANY_NAME: 638_inditex_zara_usa
# 312 rows
# K = 678 , COMPANY_NAME: 639_zumiez_zumiez
# 312 rows
# K = 679 , COMPANY_NAME: 63_aldi_aldi
# 311 rows
# K = 680 , COMPANY_NAME: 640_crossfit_crossfit
# 312 rows
# K = 681 , COMPANY_NAME: 641_ratner_companies_hair_cuttery
# 312 rows
# K = 682 , COMPANY_NAME: 642_cicis_cicis
# 312 rows
# K = 683 , COMPANY_NAME: 643_seaworld_adjusted_seaworld
# 312 rows
# K = 684 , COMPANY_NAME: 644_intercontinental_holiday_inn
# 312 rows
# K = 685 , COMPANY_NAME: 645_intercontinental_holiday_inn_express
# 312 rows
# K = 686 , COMPANY_NAME: 646_heb_central_market
# 312 rows
# K = 687 , COMPANY_NAME: 647_torchys_tacos_torchys_tacos
# 312 rows
# K = 688 , COMPANY_NAME: 648_bloomin_brands_carrabba
# 312 rows
# K = 689 , COMPANY_NAME: 649_rack_room_rack_room
# 312 rows
# K = 690 , COMPANY_NAME: 64_toast_toast
# 311 rows
# K = 691 , COMPANY_NAME: 650_pei_wei_pei_wei
# 312 rows
# K = 692 , COMPANY_NAME: 651_supervalu_adjusted_cub_foods
# 312 rows
# K = 693 , COMPANY_NAME: 652_orange_theory_orange_theory
# 312 rows
# K = 694 , COMPANY_NAME: 653_couche_tard_adjusted_kangaroo_express
# 312 rows
# K = 695 , COMPANY_NAME: 654_ocharleys_ocharleys
# 312 rows
# K = 696 , COMPANY_NAME: 655_apple_citizens_loans
# 312 rows
# K = 697 , COMPANY_NAME: 656_smart_and_final_smart_and_final
# 312 rows
# K = 698 , COMPANY_NAME: 657_dunhams_dunhams
# 312 rows
# K = 699 , COMPANY_NAME: 658_universal_studios_universal_studios
# 312 rows
# K = 700 , COMPANY_NAME: 659_fuzzys_taco_shop_fuzzys_taco_shop
# 312 rows
# K = 701 , COMPANY_NAME: 65_meijer_meijer
# 311 rows
# K = 702 , COMPANY_NAME: 660_uber_adjusted_postmates
# 55 rows
# K = 703 , COMPANY_NAME: 661_toysrus_babiesrus
# 310 rows
# K = 704 , COMPANY_NAME: 662_footlocker_adjusted_champs
# 312 rows
# K = 705 , COMPANY_NAME: 663_discount_tire_discount_tire
# 312 rows
# K = 706 , COMPANY_NAME: 664_slice_slice
# 312 rows
# K = 707 , COMPANY_NAME: 665_csc_serviceworks_csc_serviceworks
# 312 rows
# K = 708 , COMPANY_NAME: 666_mens_wearhouse_adjusted_mens_wearhouse
# 312 rows
# K = 709 , COMPANY_NAME: 667_kroger_ex_fuel_adjusted_food_4_less
# 312 rows
# K = 710 , COMPANY_NAME: 668_tailored_brands_adjusted_mens_wearhouse
# 312 rows
# K = 711 , COMPANY_NAME: 669_cimpress_vistaprint
# 312 rows
# K = 712 , COMPANY_NAME: 66_usps_usps
# 311 rows
# K = 713 , COMPANY_NAME: 670_petvalu_petvalu
# 311 rows
# K = 714 , COMPANY_NAME: 671_techstyle_fabletics
# 312 rows
# K = 715 , COMPANY_NAME: 672_pier_1_pier_1
# 312 rows
# K = 716 , COMPANY_NAME: 673_jetblue_jetblue
# 312 rows
# K = 717 , COMPANY_NAME: 674_tencent_riot_games_lol
# 312 rows
# K = 718 , COMPANY_NAME: 675_eg_group_adjusted_loaf_n_jug
# 192 rows
# K = 719 , COMPANY_NAME: 676_great_american_cookie_great_american_cookie
# 312 rows
# K = 720 , COMPANY_NAME: 677_ascena_kids_group_adjusted_justice
# 312 rows
# K = 721 , COMPANY_NAME: 678_kroger_adjusted_loaf_n_jug
# 121 rows
# K = 722 , COMPANY_NAME: 679_kroger_ex_fuel_adjusted_loaf_n_jug
# 121 rows
# K = 723 , COMPANY_NAME: 67_sonic_sonic
# 311 rows
# K = 724 , COMPANY_NAME: 680_ascena_adjusted_justice
# 312 rows
# K = 725 , COMPANY_NAME: 681_activision_blizzard_king
# 312 rows
# K = 726 , COMPANY_NAME: 682_disney_espn_plus
# 211 rows
# K = 727 , COMPANY_NAME: 683_99_cents_only_99_cents_only
# 312 rows
# K = 728 , COMPANY_NAME: 684_viagogo_stubhub
# 312 rows
# K = 729 , COMPANY_NAME: 685_newell_yankee_candle_company
# 312 rows
# K = 730 , COMPANY_NAME: 686_labcorp_labcorp
# 312 rows
# K = 731 , COMPANY_NAME: 687_stein_mart_stein_mart
# 311 rows
# K = 732 , COMPANY_NAME: 688_ancestrycom_ancestrycom
# 312 rows
# K = 733 , COMPANY_NAME: 689_darden_adjusted_yard_house
# 312 rows
# K = 734 , COMPANY_NAME: 68_amazon_prime_adjusted_amazon_prime
# 311 rows
# K = 735 , COMPANY_NAME: 690_electronic_arts_origin_com
# 312 rows
# K = 736 , COMPANY_NAME: 691_bed_bath_adjusted_buy_buy_baby
# 312 rows
# K = 737 , COMPANY_NAME: 692_albertsons_adjusted_market_street
# 312 rows
# K = 738 , COMPANY_NAME: 693_california_pizza_kitchen_california_pizza_kitchen
# 312 rows
# K = 739 , COMPANY_NAME: 694_young_living_young_living
# 312 rows
# K = 740 , COMPANY_NAME: 695_lids_lids
# 312 rows
# K = 741 , COMPANY_NAME: 696_legalshield_legalshield
# 312 rows
# K = 742 , COMPANY_NAME: 697_rite_aid_copay_adjusted_rite_aid
# 312 rows
# K = 743 , COMPANY_NAME: 698_amazon_prime_now_adjusted_amazon_prime_now
# 312 rows
# K = 744 , COMPANY_NAME: 699_microsoft_linkedin
# 312 rows
# K = 745 , COMPANY_NAME: 69_google_pay_google_payment
# 311 rows
# K = 746 , COMPANY_NAME: 700_maurices_maurices
# 312 rows
# K = 747 , COMPANY_NAME: 701_el_pollo_loco_el_pollo_loco
# 312 rows
# K = 748 , COMPANY_NAME: 702_colonial_parking_colonial_parking
# 312 rows
# K = 749 , COMPANY_NAME: 703_donatos_pizza_donatos_pizza
# 312 rows
# K = 750 , COMPANY_NAME: 704_bar_louie_bar_louie
# 312 rows
# K = 751 , COMPANY_NAME: 705_att_att_tv_now
# 248 rows
# K = 752 , COMPANY_NAME: 706_marie_callender_perkins
# 312 rows
# K = 753 , COMPANY_NAME: 707_xbox_xbox_game_pass_ultimate
# 170 rows
# K = 754 , COMPANY_NAME: 708_newks_eatery_newks_eatery
# 312 rows
# K = 755 , COMPANY_NAME: 709_save_mart_luckys
# 312 rows
# K = 756 , COMPANY_NAME: 70_comcast_comcast
# 311 rows
# K = 757 , COMPANY_NAME: 710_avis_budget
# 312 rows
# K = 758 , COMPANY_NAME: 711_big_y_big_y
# 312 rows
# K = 759 , COMPANY_NAME: 712_earth_fare_earth_fare
# 312 rows
# K = 760 , COMPANY_NAME: 713_hilton_doubletree
# 312 rows
# K = 761 , COMPANY_NAME: 714_life_time_fitness_life_time_fitness
# 312 rows
# K = 762 , COMPANY_NAME: 715_aarons_adjusted_aarons
# 312 rows
# K = 763 , COMPANY_NAME: 716_trugreen_trugreen
# 312 rows
# K = 764 , COMPANY_NAME: 717_rodan_fields_rodan_fields
# 312 rows
# K = 765 , COMPANY_NAME: 718_seaworld_adjusted_busch_gardens
# 312 rows
# K = 766 , COMPANY_NAME: 719_peloton_adjusted_peloton
# 312 rows
# K = 767 , COMPANY_NAME: 71_dominos_adjusted_dominos
# 311 rows
# K = 768 , COMPANY_NAME: 720_tijuana_flat_tijuana_flats
# 312 rows
# K = 769 , COMPANY_NAME: 721_torrid_torrid
# 312 rows
# K = 770 , COMPANY_NAME: 722_quest_diagnostics_quest_diagnostics
# 312 rows
# K = 771 , COMPANY_NAME: 723_paypal_adjusted_bill_me_later
# 312 rows
# K = 772 , COMPANY_NAME: 724_pret_a_manger_pret_a_manger
# 312 rows
# K = 773 , COMPANY_NAME: 725_bloomin_brands_bonefish_grill
# 312 rows
# K = 774 , COMPANY_NAME: 726_save_mart_save_mart
# 312 rows
# K = 775 , COMPANY_NAME: 727_hertz_hertz
# 312 rows
# K = 776 , COMPANY_NAME: 728_passport_parking_passport_parking
# 312 rows
# K = 777 , COMPANY_NAME: 729_williams_sonoma_williams_sonoma
# 312 rows
# K = 778 , COMPANY_NAME: 72_spotify_spotify
# 311 rows
# K = 779 , COMPANY_NAME: 730_sally_beauty_bsg
# 312 rows
# K = 780 , COMPANY_NAME: 731_simplisafe_simplisafe
# 312 rows
# K = 781 , COMPANY_NAME: 732_lands_end_lands_end
# 312 rows
# K = 782 , COMPANY_NAME: 733_albertsons_adjusted_united_supermarkets
# 312 rows
# K = 783 , COMPANY_NAME: 734_extra_space_storage_extra_space_storage
# 312 rows
# ...
# 311 rows
# K = 812 , COMPANY_NAME: 760_scentsy_scentsy
# 312 rows
# K = 813 , COMPANY_NAME: 761_heb_favor
# 312 rows
# K = 814 , COMPANY_NAME: 762_bark_co_bark_box
# 312 rows
# K = 815 , COMPANY_NAME: 763_wyndham_adjusted_wyndham
# 312 rows
# K = 816 , COMPANY_NAME: 764_abercrombie_abercrombie
# 312 rows
# K = 817 , COMPANY_NAME: 765_choice_hotels_comfort_inn
# 312 rows
# K = 818 , COMPANY_NAME: 766_home_chef_home_chef
# 312 rows
# K = 819 , COMPANY_NAME: 767_moneygram_moneygram
# 312 rows
# K = 820 , COMPANY_NAME: 768_regis_corp_smartstyle
# 312 rows
# K = 821 , COMPANY_NAME: 769_chicken_express_chicken_express
# 312 rows
# K = 822 , COMPANY_NAME: 76_arbys_arbys
# 311 rows
# K = 823 , COMPANY_NAME: 770_minutekey_minutekey
# 312 rows
# K = 824 , COMPANY_NAME: 771_asos_adjusted_asos
# 312 rows
# K = 825 , COMPANY_NAME: 772_twin_peaks_twin_peaks
# 312 rows
# K = 826 , COMPANY_NAME: 773_hibbett_adjusted_hibbett
# 312 rows
# K = 827 , COMPANY_NAME: 774_st_jude_st_jude
# 312 rows
# K = 828 , COMPANY_NAME: 775_dollar_tree_ex_family_dollar_adjusted_deals
# 312 rows
# K = 829 , COMPANY_NAME: 776_on_the_border_on_the_border
# 312 rows
# K = 830 , COMPANY_NAME: 777_dollar_tree_deals
# 312 rows
# K = 831 , COMPANY_NAME: 778_columbia_sportswear_columbia_sportswear
# 312 rows
# K = 832 , COMPANY_NAME: 779_williams_sonoma_pottery_barn
# 312 rows
# K = 833 , COMPANY_NAME: 77_hulu_hulu
# 311 rows
# K = 834 , COMPANY_NAME: 780_bed_bath_adjusted_christmas_tree
# 255 rows
# K = 835 , COMPANY_NAME: 781_ledo_pizza_ledo_pizza
# 312 rows
# K = 836 , COMPANY_NAME: 782_news_corp_wsj
# 312 rows
# K = 837 , COMPANY_NAME: 783_cinemark_adjusted_rave
# 312 rows
# K = 838 , COMPANY_NAME: 784_bird_bird
# 270 rows
# K = 839 , COMPANY_NAME: 785_cinemark_adjusted_century_theatre
# 312 rows
# K = 840 , COMPANY_NAME: 786_avis_avis
# 312 rows
# K = 841 , COMPANY_NAME: 787_bobby_cox_companies_rosas_cafe
# 312 rows
# K = 842 , COMPANY_NAME: 788_ascent_capital_brinks_home_security
# 312 rows
# K = 843 , COMPANY_NAME: 789_sportsmans_warehouse_sportsmans_warehouse
# 312 rows
# K = 844 , COMPANY_NAME: 78_kroger_adjusted_harris_teeter
# 311 rows
# K = 845 , COMPANY_NAME: 790_ralph_lauren_ralph_lauren
# 312 rows
# K = 846 , COMPANY_NAME: 791_moneylion_moneylion
# 312 rows
# K = 847 , COMPANY_NAME: 792_wix_com_wix_com
# 312 rows
# K = 848 , COMPANY_NAME: 793_match_group_tinder
# 312 rows
# K = 849 , COMPANY_NAME: 794_best_western_best_western
# 312 rows
# K = 850 , COMPANY_NAME: 795_windstream_holdings_windstream_holdings
# 312 rows
# K = 851 , COMPANY_NAME: 796_comcast_peacock
# 307 rows
# K = 852 , COMPANY_NAME: 797_hilton_hilton_garden_inn
# 312 rows
# K = 853 , COMPANY_NAME: 798_h_r_block_h_r_retail
# 312 rows
# K = 854 , COMPANY_NAME: 799_chegg_adjusted_chegg_other
# 312 rows
# K = 855 , COMPANY_NAME: 79_kroger_ex_fuel_adjusted_harris_teeter
# 311 rows
# K = 856 , COMPANY_NAME: 800_coffee_bean_and_tea_leaf_coffee_bean_and_tea_leaf
# 312 rows
# K = 857 , COMPANY_NAME: 801_1800flowers_com_adjusted_1800flowers_com
# 312 rows
# K = 858 , COMPANY_NAME: 802_overstock_com_overstock_com
# 312 rows
# K = 859 , COMPANY_NAME: 803_ascena_plus_group_adjusted_lane_bryant
# 312 rows
# K = 860 , COMPANY_NAME: 804_kroger_adjusted_city_market
# 312 rows
# K = 861 , COMPANY_NAME: 805_bowlero_amf
# 312 rows
# K = 862 , COMPANY_NAME: 806_kroger_ex_fuel_adjusted_city_market
# 312 rows
# K = 863 , COMPANY_NAME: 807_ascena_adjusted_lane_bryant
# 312 rows
# K = 864 , COMPANY_NAME: 808_freebirds_world_burrito_freebirds_world_burrito
# 312 rows
# K = 865 , COMPANY_NAME: 809_hyatt_hyatt_regency
# 312 rows
# K = 866 , COMPANY_NAME: 80_kohl_kohl
# 311 rows
# K = 867 , COMPANY_NAME: 810_squarespace_squarespace
# 312 rows
# K = 868 , COMPANY_NAME: 811_big_5_big_5
# 312 rows
# K = 869 , COMPANY_NAME: 812_cricut_cricut
# 312 rows
# K = 870 , COMPANY_NAME: 813_main_event_main_event
# 312 rows
# K = 871 , COMPANY_NAME: 814_quiznos_quiznos
# 312 rows
# K = 872 , COMPANY_NAME: 815_newegg_newegg
# 312 rows
# K = 873 , COMPANY_NAME: 816_acima_acima
# 312 rows
# K = 874 , COMPANY_NAME: 817_jd_sports_adjusted_finish_line
# 183 rows
# K = 875 , COMPANY_NAME: 818_marriott_westin
# 312 rows
# K = 876 , COMPANY_NAME: 819_avant_avant
# 312 rows
# K = 877 , COMPANY_NAME: 81_berkshire_hathaway_dairy_queen
# 311 rows
# K = 878 , COMPANY_NAME: 820_ez_pass_fastrak
# 312 rows
# K = 879 , COMPANY_NAME: 821_transunion_transunion
# 312 rows
# K = 880 , COMPANY_NAME: 822_crate_barrel_crate_barrel
# 312 rows
# K = 881 , COMPANY_NAME: 823_tillys_tillys
# 312 rows
# K = 882 , COMPANY_NAME: 824_great_wolf_lodge_great_wolf_lodge
# 312 rows
# K = 883 , COMPANY_NAME: 825_terminix_terminix
# 312 rows
# K = 884 , COMPANY_NAME: 826_fiserv_clover
# 312 rows
# K = 885 , COMPANY_NAME: 827_brookshire_brothers_brookshire_brothers
# 312 rows
# K = 886 , COMPANY_NAME: 828_terminix_adjusted_terminix
# 312 rows
# K = 887 , COMPANY_NAME: 829_harley_davidson_harley_davidson
# 312 rows
# K = 888 , COMPANY_NAME: 830_key_food_key_food
# 312 rows
# K = 889 , COMPANY_NAME: 831_xsolla_xsolla
# 312 rows
# K = 890 , COMPANY_NAME: 832_supervalu_adjusted_shop_n_save
# 312 rows
# K = 891 , COMPANY_NAME: 833_remitly_remitly
# 312 rows
# K = 892 , COMPANY_NAME: 834_amazon_fresh_adjusted_amazon_fresh
# 305 rows
# K = 893 , COMPANY_NAME: 835_snap_on_snap_on
# 312 rows
# K = 894 , COMPANY_NAME: 836_piada_italian_street_food_piada_italian_street_food
# 312 rows
# K = 895 , COMPANY_NAME: 837_facebook_oculus
# 312 rows
# K = 896 , COMPANY_NAME: 838_citi_trends_citi_trends
# 312 rows
# K = 897 , COMPANY_NAME: 839_alamo_drafthouse_cincema_alamo_drafhouse_cinema
# 312 rows
# K = 898 , COMPANY_NAME: 83_charter_charter
# 311 rows
# K = 899 , COMPANY_NAME: 840_embrace_pet_insurance_embrace_pet_insurance
# 312 rows
# K = 900 , COMPANY_NAME: 841_wow_wow
# 312 rows
# K = 901 , COMPANY_NAME: 842_ooma_ooma
# 312 rows
# K = 902 , COMPANY_NAME: 843_tapestry_adjusted_coach
# 312 rows
# K = 903 , COMPANY_NAME: 844_bevmo_bevmo
# 312 rows
# K = 904 , COMPANY_NAME: 845_pandora_jewelry_pandora_jewelry
# 312 rows
# K = 905 , COMPANY_NAME: 846_eg_group_adjusted_kwik_shop
# 192 rows
# K = 906 , COMPANY_NAME: 847_golfnow_golfnow
# 312 rows
# K = 907 , COMPANY_NAME: 848_world_vision_world_vision
# 312 rows
# K = 908 , COMPANY_NAME: 849_dish_adjusted_boost_mobile
# 77 rows
# K = 909 , COMPANY_NAME: 84_marmaxx_adjusted_tj_maxx
# 311 rows
# K = 910 , COMPANY_NAME: 850_expedia_adjusted_home_away
# 312 rows
# K = 911 , COMPANY_NAME: 851_cato_cato
# 312 rows
# K = 912 , COMPANY_NAME: 852_eat24_adjusted_eat24
# 310 rows
# K = 913 , COMPANY_NAME: 853_stamps_adjusted_stamps
# 312 rows
# K = 914 , COMPANY_NAME: 854_vonage_vonage
# 312 rows
# K = 915 , COMPANY_NAME: 855_la_madeleine_la_madeleine
# 312 rows
# K = 916 , COMPANY_NAME: 856_fabfitfun_fabfitfun
# 312 rows
# K = 917 , COMPANY_NAME: 857_rockauto_rockauto
# 312 rows
# K = 918 , COMPANY_NAME: 858_chopt_chopt
# 312 rows
# K = 919 , COMPANY_NAME: 859_lightspeed_payments_lightspeed_payments
# 312 rows
# K = 920 , COMPANY_NAME: 85_tjx_adjusted_tj_maxx
# 311 rows
# K = 921 , COMPANY_NAME: 860_hard_rock_hard_rock
# 312 rows
# K = 922 , COMPANY_NAME: 861_macy_adjusted_bloomingdale
# 312 rows
# K = 923 , COMPANY_NAME: 862_prosper_prosper
# 312 rows
# K = 924 , COMPANY_NAME: 863_kroger_adjusted_jay_c_foods
# 312 rows
# K = 925 , COMPANY_NAME: 864_build_a_bear_build_a_bear
# 312 rows
# K = 926 , COMPANY_NAME: 865_fleet_farm_fleet_farm
# 312 rows
# K = 927 , COMPANY_NAME: 866_peak_games_peak_games
# 312 rows
# K = 928 , COMPANY_NAME: 867_canva_canva
# 312 rows
# K = 929 , COMPANY_NAME: 868_crocs_crocs
# 312 rows
# K = 930 , COMPANY_NAME: 869_greyhound_lines_greyhound_lines
# 312 rows
# K = 931 , COMPANY_NAME: 86_rite_aid_rite_aid
# 311 rows
# K = 932 , COMPANY_NAME: 870_scheels_scheels
# 312 rows
# K = 933 , COMPANY_NAME: 871_dell_dell
# 312 rows
# K = 934 , COMPANY_NAME: 872_marriott_fairfield_inn
# 312 rows
# K = 935 , COMPANY_NAME: 873_adore_me_adore_me
# 312 rows
# K = 936 , COMPANY_NAME: 874_waitr_adjusted_waitr
# 312 rows
# K = 937 , COMPANY_NAME: 875_tophatter_tophatter
# 312 rows
# K = 938 , COMPANY_NAME: 876_sofi_sofi_payments
# 312 rows
# K = 939 , COMPANY_NAME: 877_pampered_chef_pampered_chef
# 312 rows
# K = 940 , COMPANY_NAME: 878_styleseat_styleseat
# 312 rows
# K = 941 , COMPANY_NAME: 879_evine_evine
# 312 rows
# K = 942 , COMPANY_NAME: 87_dollar_tree_family_dollar
# 312 rows
# K = 943 , COMPANY_NAME: 880_exelon_delmarva_power
# 312 rows
# K = 944 , COMPANY_NAME: 881_kroger_ex_fuel_adjusted_home_chef
# 183 rows
# K = 945 , COMPANY_NAME: 882_spothero_spothero
# 312 rows
# K = 946 , COMPANY_NAME: 883_choice_hotels_quality_inn
# 312 rows
# K = 947 , COMPANY_NAME: 884_gymboree_adjusted_gymboree
# 312 rows
# K = 948 , COMPANY_NAME: 885_kroger_adjusted_home_chef
# 183 rows
# K = 949 , COMPANY_NAME: 886_snap_financing_snap_financing
# 312 rows
# K = 950 , COMPANY_NAME: 887_burgerfi_burgerfi
# 312 rows
# K = 951 , COMPANY_NAME: 888_j_crew_madewell
# 312 rows
# K = 952 , COMPANY_NAME: 889_kickstarter_kickstarter
# 312 rows
# K = 953 , COMPANY_NAME: 88_rite_aid_adjusted_rite_aid
# 312 rows
# K = 954 , COMPANY_NAME: 890_pita_pit_pita_pit
# 312 rows
# K = 955 , COMPANY_NAME: 891_eatstreet_eatstreet
# 312 rows
# K = 956 , COMPANY_NAME: 892_la_quinta_la_quinta
# 312 rows
# K = 957 , COMPANY_NAME: 893_washington_post_washington_post
# 312 rows
# K = 958 , COMPANY_NAME: 894_crowdstar_glu
# 312 rows
# K = 959 , COMPANY_NAME: 895_gogo_gogo
# 312 rows
# K = 960 , COMPANY_NAME: 896_skechers_skechers
# 312 rows
# K = 961 , COMPANY_NAME: 897_lubys_fuddruckers
# 312 rows
# K = 962 , COMPANY_NAME: 898_signet_kay
# 312 rows
# K = 963 , COMPANY_NAME: 899_nestle_adjusted_nespresso
# 312 rows
# K = 964 , COMPANY_NAME: 89_murphy_adjusted_murphy
# 312 rows
# K = 965 , COMPANY_NAME: 900_wetzels_pretzels_wetzels_pretzels
# 312 rows
# K = 966 , COMPANY_NAME: 901_charming_charlie_charming_charlie
# 312 rows
# K = 967 , COMPANY_NAME: 902_signet_adjusted_kay
# 312 rows
# K = 968 , COMPANY_NAME: 903_kate_spade_kate_spade
# 312 rows
# K = 969 , COMPANY_NAME: 904_allstate_esurance
# 312 rows
# K = 970 , COMPANY_NAME: 905_kroger_fuel_adjusted_smiths
# 312 rows
# K = 971 , COMPANY_NAME: 906_golden_chick_golden_chick
# 312 rows
# K = 972 , COMPANY_NAME: 907_paymentus_paymentus
# 312 rows
# K = 973 , COMPANY_NAME: 908_albertsons_adjusted_carrs
# 312 rows
# K = 974 , COMPANY_NAME: 909_techstyle_justfab
# 312 rows
# K = 975 , COMPANY_NAME: 90_giant_eagle_giant_eagle
# 312 rows
# K = 976 , COMPANY_NAME: 910_mcafee_mcafee
# 312 rows
# K = 977 , COMPANY_NAME: 911_us_cellular_us_cellular
# 312 rows
# K = 978 , COMPANY_NAME: 912_birchbox_birchbox
# 312 rows
# K = 979 , COMPANY_NAME: 913_payrange_payrange
# 312 rows
# K = 980 , COMPANY_NAME: 914_buckle_buckle
# 312 rows
# K = 981 , COMPANY_NAME: 915_duluth_trading_duluth_trading
# 312 rows
# K = 982 , COMPANY_NAME: 916_taco_bueno_taco_bueno
# 312 rows
# K = 983 , COMPANY_NAME: 917_tapingo_tapingo
# 312 rows
# K = 984 , COMPANY_NAME: 918_famous_daves_famous_daves
# 312 rows
# K = 985 , COMPANY_NAME: 919_cedar_fair_adjusted_cedar_point
# 312 rows
# K = 986 , COMPANY_NAME: 91_trader_joe_trader_joe
# 312 rows
# K = 987 , COMPANY_NAME: 920_retro_fitness_retro_fitness
# 312 rows
# K = 988 , COMPANY_NAME: 921_vf_corp_adjusted_north_face
# 312 rows
# K = 989 , COMPANY_NAME: 922_vera_bradley_adjusted_vera_bradley
# 312 rows
# K = 990 , COMPANY_NAME: 923_goodyear_auto_adjusted_goodyear_auto
# 312 rows
# K = 991 , COMPANY_NAME: 924_redbubble_redbubble
# 312 rows
# K = 992 , COMPANY_NAME: 925_marriott_residence_inn
# 312 rows
# K = 993 , COMPANY_NAME: 926_shopko_shopko
# 312 rows
# K = 994 , COMPANY_NAME: 927_kroger_ex_fuel_adjusted_jay_c_foods
# 312 rows
# K = 995 , COMPANY_NAME: 928_slim_chickens_slim_chickens
# 312 rows
# K = 996 , COMPANY_NAME: 929_genesco_adjusted_lids
# 163 rows
# K = 997 , COMPANY_NAME: 92_xbox_xbox
# 312 rows
# K = 998 , COMPANY_NAME: 930_hilton_embassy_suites
# 312 rows
# K = 999 , COMPANY_NAME: 931_caviar_adjusted_caviar
# 312 rows
# K = 1000 , COMPANY_NAME: 932_bite_squad_adjusted_bite_squad
# 312 rows
# K = 1001 , COMPANY_NAME: 933_honeygrow_honeygrow
# 312 rows
# K = 1002 , COMPANY_NAME: 934_square_caviar
# 312 rows
# K = 1003 , COMPANY_NAME: 935_world_of_beer_world_of_beer
# 312 rows
# K = 1004 , COMPANY_NAME: 936_it_works_it_works
# 312 rows
# K = 1005 , COMPANY_NAME: 937_boingo_boingo
# 312 rows
# K = 1006 , COMPANY_NAME: 938_webull_webull
# 187 rows
# K = 1007 , COMPANY_NAME: 939_schwans_home_service_schwans_home_service
# 312 rows
# K = 1008 , COMPANY_NAME: 93_pilot_flying_j_pilot_flying_j
# 312 rows
# K = 1009 , COMPANY_NAME: 940_kroger_adjusted_kwik_shop
# 121 rows
# K = 1010 , COMPANY_NAME: 941_grove_collaborative_grove_collaborative
# 312 rows
# K = 1011 , COMPANY_NAME: 942_echostar_hughesnet
# 312 rows
# K = 1012 , COMPANY_NAME: 943_scopely_scopely
# 312 rows
# K = 1013 , COMPANY_NAME: 944_ftd_adjusted_ftd
# 312 rows
# K = 1014 , COMPANY_NAME: 945_levi_levi
# 312 rows
# K = 1015 , COMPANY_NAME: 946_kroger_ex_fuel_adjusted_kwik_shop
# 121 rows
# K = 1016 , COMPANY_NAME: 947_kors_adjusted_kors
# 312 rows
# K = 1017 , COMPANY_NAME: 948_avis_zipcar
# 312 rows
# K = 1018 , COMPANY_NAME: 949_gander_mountain_gander_mountain
# 312 rows
# K = 1019 , COMPANY_NAME: 94_playstation_playstation
# 312 rows
# K = 1020 , COMPANY_NAME: 950_microsoft_skype
# 312 rows
# K = 1021 , COMPANY_NAME: 951_zips_car_wash_zips_car_wash
# 312 rows
# K = 1022 , COMPANY_NAME: 952_discord_discord
# 308 rows
# K = 1023 , COMPANY_NAME: 953_wyndham_adjusted_days_inn
# 312 rows
# K = 1024 , COMPANY_NAME: 954_epic_games_fortnite
# 311 rows
# K = 1025 , COMPANY_NAME: 955_melaleuca_melaleuca
# 312 rows
# K = 1026 , COMPANY_NAME: 956_kindercare_kindercare
# 312 rows
# K = 1027 , COMPANY_NAME: 957_chicos_chicos
# 312 rows
# K = 1028 , COMPANY_NAME: 958_rosatis_rosatis
# 312 rows
# K = 1029 , COMPANY_NAME: 959_talbots_talbots
# 312 rows
# K = 1030 , COMPANY_NAME: 95_ebay_ebay
# 312 rows
# K = 1031 , COMPANY_NAME: 960_lexington_law_lexington_law
# 312 rows
# K = 1032 , COMPANY_NAME: 961_wise_wise
# 311 rows
# K = 1033 , COMPANY_NAME: 962_fast_retailing_uniqlo
# 312 rows
# K = 1034 , COMPANY_NAME: 963_foxs_pizza_den_foxs_pizza_den
# 312 rows
# K = 1035 , COMPANY_NAME: 964_freds_freds
# 312 rows
# K = 1036 , COMPANY_NAME: 965_imperfect_foods_imperfect_foods
# 310 rows
# K = 1037 , COMPANY_NAME: 966_chicos_white_house_black_market
# 312 rows
# K = 1038 , COMPANY_NAME: 967_old_chicago_pizza_old_chicago_pizza
# 312 rows
# K = 1039 , COMPANY_NAME: 968_hillman_group_adjusted_minutekey
# 175 rows
# K = 1040 , COMPANY_NAME: 969_billie_billie
# 214 rows
# K = 1041 , COMPANY_NAME: 96_yum_pizza_hut_kfc
# 312 rows
# K = 1042 , COMPANY_NAME: 970_freds_adjusted_freds
# 312 rows
# K = 1043 , COMPANY_NAME: 971_beef_obrady_beef_obrady
# 312 rows
# K = 1044 , COMPANY_NAME: 972_savers_savers
# 312 rows
# K = 1045 , COMPANY_NAME: 973_cosi_cosi
# 312 rows
# K = 1046 , COMPANY_NAME: 974_national_vision_americas_best
# 312 rows
# K = 1047 , COMPANY_NAME: 975_lulus_lulus
# 312 rows
# K = 1048 , COMPANY_NAME: 976_brinker_maggianos
# 312 rows
# K = 1049 , COMPANY_NAME: 977_leslies_pool_supply_leslies_pool_supply
# 312 rows
# K = 1050 , COMPANY_NAME: 978_fiverr_fiverr
# 312 rows
# K = 1051 , COMPANY_NAME: 979_take_5_oil_change_take_5_oil_change
# 312 rows
# K = 1052 , COMPANY_NAME: 97_amazon_adjusted_whole_foods
# 225 rows
# K = 1053 , COMPANY_NAME: 980_disney_epcot
# 312 rows
# K = 1054 , COMPANY_NAME: 981_marble_slab_creamery_marble_slab_creamery
# 312 rows
# K = 1055 , COMPANY_NAME: 982_guitar_center_music_and_arts
# 312 rows
# K = 1056 , COMPANY_NAME: 983_metro_diner_metro_diner
# 312 rows
# K = 1057 , COMPANY_NAME: 984_cedar_fair_adjusted_kings_island
# 312 rows
# K = 1058 , COMPANY_NAME: 985_wealthfront_wealthfront
# 303 rows
# K = 1059 , COMPANY_NAME: 986_dressbarn_dressbarn
# 312 rows
# K = 1060 , COMPANY_NAME: 987_original_pancake_house_original_pancake_house
# 312 rows
# K = 1061 , COMPANY_NAME: 988_jet_com_adjusted_jet_com
# 312 rows
# K = 1062 , COMPANY_NAME: 989_hyatt_hyatt
# 312 rows
# K = 1063 , COMPANY_NAME: 98_jimmy_johns_jimmy_johns
# 312 rows
# K = 1064 , COMPANY_NAME: 990_tesla_tesla
# 312 rows
# K = 1065 , COMPANY_NAME: 991_floor_decor_floor_decor
# 312 rows
# K = 1066 , COMPANY_NAME: 992_amazon_web_services_amazon_web_services
# 312 rows
# K = 1067 , COMPANY_NAME: 993_expedia_adjusted_vrbo
# 312 rows
# K = 1068 , COMPANY_NAME: 994_cubesmart_cubesmart
# 312 rows
# K = 1069 , COMPANY_NAME: 995_guardian_protection_services_guardian_protection_services
# 312 rows
# K = 1070 , COMPANY_NAME: 996_williams_sonoma_pottery_barn_kids
# 312 rows
# K = 1071 , COMPANY_NAME: 997_urban_free_people
# 312 rows
# K = 1072 , COMPANY_NAME: 998_thirty_one_gifts_thirty_one_gifts
# 312 rows
# K = 1073 , COMPANY_NAME: 999_darden_adjusted_bahama_breeze
# 312 rows
# K = 1074 , COMPANY_NAME: 99_ahold_delhaize_adjusted_giant_carlisle
# 312 rows

# %%
### sanity check
total_df = pd.concat(data_df_list).reset_index(drop=True)
print(total_df.groupby(['merchant_index'])['merchant_index'].count())
total_df
# Out:
# merchant_index
# 100     177
# 101     177
# 102     177
# 103     177
# 104     177
#        ...
# 1086    177
# 1087    177
# 1088    177
# 1089    177
# 1090    177
# Name: merchant_index, Length: 100, dtype: int64
# component   acq_week  N_week_cohort  initial_order  initial_order_per_cust  \
# 0         2017-03-12          534.0          534.0                     1.0
# 1         2017-03-19          419.0          419.0                     1.0
# 2         2017-03-26          203.0          203.0                     1.0
# 3         2017-04-02          182.0          182.0                     1.0
# 4         2017-04-09          118.0          118.0                     1.0
# ...              ...            ...            ...                     ...
# 17437     2020-01-26          405.0          405.0                     1.0
# 17438     2020-02-02          451.0          451.0                     1.0
# 17439     2020-02-09          635.0          635.0                     1.0
# 17440     2020-02-16          590.0          590.0                     1.0
# 17441     2020-02-23          503.0          503.0                     1.0
#
# component  initial_spend  initial_aov  orders  orders_per_cust      spend  \
# 0               2788.401     5.221725   931.0         1.743446   4827.361
# 1               1742.820     4.159475   635.0         1.515513   2590.120
# 2               1044.471     5.145177   320.0         1.576355   1505.301
# 3                685.540     3.766703   272.0         1.494505   1125.640
# 4                457.820     3.879831   156.0         1.322034    652.440
# ...                  ...          ...     ...              ...        ...
# 17437          29391.245    72.570975   415.0         1.024691  29971.675
# 17438          32238.135    71.481452   461.0         1.022173  33040.795
# 17439          51340.315    80.850890   654.0         1.029921  52836.305
# 17440          39305.815    66.620025   602.0         1.020339  39840.125
# 17441          39521.875    78.572316   517.0         1.027833  40554.075
#
# component        aov  year  holidays  weekofyear    linear  linear_1  \
# 0           5.185135   0.0       0.0        10.0  0.000000  0.000000
# 1           4.078929   0.0       0.0        11.0  0.006494  0.000042
# 2           4.704066   0.0       0.0        12.0  0.012987  0.000169
# 3           4.138382   0.0       0.0        13.0  0.019481  0.000379
# 4           4.182308   0.0       0.0        14.0  0.025974  0.000675
# ...              ...   ...       ...         ...       ...       ...
# 17437      72.220904   1.0       0.0         4.0  0.977273  0.955062
# 17438      71.672007   1.0       0.0         5.0  0.982955  0.966200
# 17439      80.789457   1.0       0.0         6.0  0.988636  0.977402
# 17440      66.179610   1.0       0.0         7.0  0.994318  0.988669
# 17441      78.441151   1.0       0.0         8.0  1.000000  1.000000
#
# component  merchant_index         merchant               category  \
# 0                    1000     jam_city_inc     Home Entertainment
# 1                    1000     jam_city_inc     Home Entertainment
# 2                    1000     jam_city_inc     Home Entertainment
# 3                    1000     jam_city_inc     Home Entertainment
# 4                    1000     jam_city_inc     Home Entertainment
# ...                   ...              ...                    ...
# 17437                1090  piercing_pagoda  Apparel & Accessories
# 17438                1090  piercing_pagoda  Apparel & Accessories
# 17439                1090  piercing_pagoda  Apparel & Accessories
# 17440                1090  piercing_pagoda  Apparel & Accessories
# 17441                1090  piercing_pagoda  Apparel & Accessories
#
# component        subcategory
# 0                     Gaming
# 1                     Gaming
# 2                     Gaming
# 3                     Gaming
# 4                     Gaming
# ...                      ...
# 17437      Jewelry & Watches
# 17438      Jewelry & Watches
# 17439      Jewelry & Watches
# 17440      Jewelry & Watches
# 17441      Jewelry & Watches
#
# [17442 rows x 19 columns]

# %%
### why 177 rows
total_df[total_df['merchant_index']==99]
# Out:
# component   acq_week  N_week_cohort  initial_order  initial_order_per_cust  \
# 185116    2016-10-09         1769.0         1769.0                     1.0
# 185117    2016-10-16         1718.0         1718.0                     1.0
# 185118    2016-10-23         1616.0         1616.0                     1.0
# 185119    2016-10-30         1546.0         1546.0                     1.0
# 185120    2016-11-06         1642.0         1642.0                     1.0
# ...              ...            ...            ...                     ...
# 185288    2020-01-26          416.0          416.0                     1.0
# 185289    2020-02-02          412.0          412.0                     1.0
# 185290    2020-02-09          431.0          431.0                     1.0
# 185291    2020-02-16          472.0          472.0                     1.0
# 185292    2020-02-23          411.0          411.0                     1.0
#
# component  initial_spend  initial_aov  orders  orders_per_cust       spend  \
# 185116        82120.0025    46.421709  2006.0         1.133974  89787.2925
# 185117        69498.2325    40.452987  1998.0         1.162980  80214.1500
# 185118        66779.4225    41.323900  1872.0         1.158416  76603.8000
# 185119        66481.5400    43.002290  1748.0         1.130660  72643.5000
# 185120        64692.1375    39.398379  1859.0         1.132156  71081.6275
# ...                  ...          ...     ...              ...         ...
# 185288        25152.6050    60.462993   455.0         1.093750  26612.8150
# 185289        16633.9875    40.373756   460.0         1.116505  24246.5000
# 185290        15475.4175    35.905841   478.0         1.109049  17257.9075
# 185291        21682.0825    45.936615   530.0         1.122881  23671.3225
# 185292        26675.3125    64.903437   441.0         1.072993  27608.8225
#
# component        aov  year  holidays  weekofyear    linear  linear_1  \
# 185116     44.759368   0.0       0.0        40.0  0.000000  0.000000
# 185117     40.147222   0.0       0.0        41.0  0.005682  0.000032
# 185118     40.920833   0.0       0.0        42.0  0.011364  0.000129
# 185119     41.558066   0.0       0.0        43.0  0.017045  0.000291
# 185120     38.236486   0.0       0.0        44.0  0.022727  0.000517
# ...              ...   ...       ...         ...       ...       ...
# 185288     58.489703   1.0       0.0         4.0  0.977273  0.955062
# 185289     52.709783   1.0       0.0         5.0  0.982955  0.966200
# 185290     36.104409   1.0       0.0         6.0  0.988636  0.977402
# 185291     44.662873   1.0       0.0         7.0  0.994318  0.988669
# 185292     62.605040   1.0       0.0         8.0  1.000000  1.000000
#
# component  merchant_index        merchant category   subcategory
# 185116                 99  giant_carlisle  Grocers  Supermarkets
# 185117                 99  giant_carlisle  Grocers  Supermarkets
# 185118                 99  giant_carlisle  Grocers  Supermarkets
# 185119                 99  giant_carlisle  Grocers  Supermarkets
# 185120                 99  giant_carlisle  Grocers  Supermarkets
# ...                   ...             ...      ...           ...
# 185288                 99  giant_carlisle  Grocers  Supermarkets
# 185289                 99  giant_carlisle  Grocers  Supermarkets
# 185290                 99  giant_carlisle  Grocers  Supermarkets
# 185291                 99  giant_carlisle  Grocers  Supermarkets
# 185292                 99  giant_carlisle  Grocers  Supermarkets
#
# [177 rows x 19 columns]

# %%
## sanity check

K = 277 # COMPANY_NAME: 267_irs_payments_adjusted_stimulus_payouts
# this company is dropped because it starts after the end of period

## choose company
COMPANY_NAME = os.path.splitext(os.path.split(filelist[K])[1])[0][:-len('_cohort')]
FILEPATH = os.path.splitext(os.path.split(filelist[K])[1])[0] + '.csv'
print('K =', K, ', COMPANY_NAME:', COMPANY_NAME)

## read company
COL_NAMES_TO_READ = ['acq_week', # group identifier
                'week', 'tenure', # time identifier
            #  'spend', # target
                'N_week_cohort', 'acq_quarter', 'merchant_index', 'merchant'] 

raw_df = pd.read_csv(f'{READ_DIR}/{FILEPATH}') 
                # usecols=COL_NAMES_TO_READ)[COL_NAMES_TO_READ]

raw_df=raw_df[raw_df['tenure']==0] # pick one obs per each acq_week
print(raw_df.shape[0], 'rows')
raw_df.sort_values('acq_week')
# Out:
# K = 277 , COMPANY_NAME: 267_irs_payments_adjusted_stimulus_payouts
# 88 rows
#         acq_week        week  tenure acq_quarter  merchant_index  \
# 0     2020-04-05  2020-04-05       0  2020-04-01             267
# 88    2020-04-12  2020-04-12       0  2020-04-01             267
# 175   2020-04-19  2020-04-19       0  2020-04-01             267
# 261   2020-04-26  2020-04-26       0  2020-04-01             267
# 346   2020-05-03  2020-05-03       0  2020-04-01             267
# ...          ...         ...     ...         ...             ...
# 3901  2021-11-07  2021-11-07       0  2021-10-01             267
# 3906  2021-11-14  2021-11-14       0  2021-10-01             267
# 3910  2021-11-21  2021-11-21       0  2021-10-01             267
# 3913  2021-11-28  2021-11-28       0  2021-10-01             267
# 3915  2021-12-05  2021-12-05       0  2021-10-01             267
#
#               merchant        parent_merchant category     subcategory  \
# 0     stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 88    stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 175   stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 261   stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 346   stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# ...                ...                    ...      ...             ...
# 3901  stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 3906  stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 3910  stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 3913  stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
# 3915  stimulus_payouts  irs_payments_adjusted  Finance  Money Transfer
#
#       N_week_cohort  active_users   orders  rpt_orders         spend  \
# 0               190           190      191           1  4.221000e+05
# 88          1258432       1258432  1296899       38467  2.813221e+09
# 175           18279         18279    18349          70  3.378490e+07
# 261           95657         95657    96399         742  1.828341e+08
# 346           49210         49210    49306          96  1.127640e+08
# ...             ...           ...      ...         ...           ...
# 3901            449           449      449           0  1.315261e+06
# 3906            191           191      192           1  5.372639e+05
# 3910            141           141      141           0  4.484992e+05
# 3913            254           254      254           0  7.050901e+05
# 3915            112           112      112           0  2.975146e+05
#
#        rpt_spend  initial_order  initial_spend  initial_aov
# 0         2200.0            190   4.199000e+05  2210.000000
# 88    73419800.0        1258432   2.739801e+09  2177.154507
# 175     121800.0          18279   3.366310e+07  1841.627004
# 261    1330700.0          95657   1.815034e+08  1897.439811
# 346     174000.0          49210   1.125900e+08  2287.949604
# ...          ...            ...            ...          ...
# 3901         0.0            449   1.315261e+06  2929.312405
# 3906      1400.0            191   5.358639e+05  2805.570262
# 3910         0.0            141   4.484992e+05  3180.845390
# 3913         0.0            254   7.050901e+05  2775.945354
# 3915         0.0            112   2.975146e+05  2656.380000
#
# [88 rows x 18 columns]

# %%
## sanity check

K = 369 # COMPANY_NAME: 353_kroger_ex_fuel_adjusted_turkey_hill
# this company is dropped because it has no data in prediction period

## choose company
COMPANY_NAME = os.path.splitext(os.path.split(filelist[K])[1])[0][:-len('_cohort')]
FILEPATH = os.path.splitext(os.path.split(filelist[K])[1])[0] + '.csv'
print('K =', K, ', COMPANY_NAME:', COMPANY_NAME)

## read company
COL_NAMES_TO_READ = ['acq_week', # group identifier
                'week', 'tenure', # time identifier
            #  'spend', # target
                'N_week_cohort', 'acq_quarter', 'merchant_index', 'merchant'] 

raw_df = pd.read_csv(f'{READ_DIR}/{FILEPATH}') 
                # usecols=COL_NAMES_TO_READ)[COL_NAMES_TO_READ]

raw_df=raw_df[raw_df['tenure']==0] # pick one obs per each acq_week
print(raw_df.shape[0], 'rows')
raw_df.sort_values('acq_week')
# Out:
# K = 369 , COMPANY_NAME: 353_kroger_ex_fuel_adjusted_turkey_hill
# 121 rows
#         acq_week        week  tenure acq_quarter  merchant_index     merchant  \
# 0     2015-12-27  2015-12-27       0  2015-10-01             353  turkey_hill
# 121   2016-01-03  2016-01-03       0  2016-01-01             353  turkey_hill
# 241   2016-01-10  2016-01-10       0  2016-01-01             353  turkey_hill
# 360   2016-01-17  2016-01-17       0  2016-01-01             353  turkey_hill
# 478   2016-01-24  2016-01-24       0  2016-01-01             353  turkey_hill
# ...          ...         ...     ...         ...             ...          ...
# 7366  2018-03-18  2018-03-18       0  2018-01-01             353  turkey_hill
# 7371  2018-03-25  2018-03-25       0  2018-01-01             353  turkey_hill
# 7375  2018-04-01  2018-04-01       0  2018-04-01             353  turkey_hill
# 7378  2018-04-08  2018-04-08       0  2018-04-01             353  turkey_hill
# 7380  2018-04-15  2018-04-15       0  2018-04-01             353  turkey_hill
#
#               parent_merchant category        subcategory  N_week_cohort  \
# 0     kroger_ex_fuel_adjusted  Grocers  Specialty Grocers           5688
# 121   kroger_ex_fuel_adjusted  Grocers  Specialty Grocers          10505
# 241   kroger_ex_fuel_adjusted  Grocers  Specialty Grocers           5872
# 360   kroger_ex_fuel_adjusted  Grocers  Specialty Grocers           3921
# 478   kroger_ex_fuel_adjusted  Grocers  Specialty Grocers           2686
# ...                       ...      ...                ...            ...
# 7366  kroger_ex_fuel_adjusted  Grocers  Specialty Grocers            461
# 7371  kroger_ex_fuel_adjusted  Grocers  Specialty Grocers            524
# 7375  kroger_ex_fuel_adjusted  Grocers  Specialty Grocers            510
# 7378  kroger_ex_fuel_adjusted  Grocers  Specialty Grocers            408
# 7380  kroger_ex_fuel_adjusted  Grocers  Specialty Grocers            294
#
#       active_users  orders  rpt_orders      spend  rpt_spend
# 0             5688    7237        1549  148601.19   26159.36
# 121          10505   16045        5540  346715.25  104244.56
# 241           5872    7472        1600  150998.60   28063.58
# 360           3921    4787         866   86976.57   14175.15
# 478           2686    3154         468   57607.15    8856.21
# ...            ...     ...         ...        ...        ...
# 7366           461     508          47   11984.66     785.77
# 7371           524     586          62   15825.21    1227.40
# 7375           510     585          75   14377.47    1152.73
# 7378           408     452          44   12720.26     655.34
# 7380           294     320          26    7360.64     504.75
#
# [121 rows x 15 columns]

# %%
READ_DIR
# Out:
# '/home/jhan405/cbcv/tft_google_ver4/jianlin-tft/data/weekly_cohort_data_1000'

# %%
import pandas as pd
raw_df = pd.read_csv('/home/jhan405/cbcv/tft_google_ver4/jianlin-tft/data/preprocessed_data/tft_google/company_0_100_acq_initaov.csv') 
# raw_df = raw_df.drop(columns = ['Unnamed: 0'])
raw_df = raw_df.drop(columns = ['V1'])
raw_df = raw_df.sort_values(['merchant_index', 'acq_week'])

raw_df[['aov', 'initial_aov']] = raw_df[['aov', 'initial_aov']].fillna(method = 'ffill') # propagate non-null values forward
raw_df
# raw_df.to_csv('/home/jhan405/cbcv/tft_google_ver4/jianlin-tft/data/preprocessed_data/tft_google/company_0_100_acq_initaov.csv')

# %%
import pandas as pd
raw_df = pd.read_csv('/home/jhan405/cbcv/tft_google_ver4/jianlin-tft/data/preprocessed_data/tft_google/company_0_1000_acq_initaov.csv') 
raw_df = raw_df.drop(columns = ['Unnamed: 0'])
# raw_df = raw_df.drop(columns = ['V1'])
raw_df = raw_df.sort_values(['merchant_index', 'acq_week'])

raw_df[['aov', 'initial_aov']] = raw_df[['aov', 'initial_aov']].fillna(method = 'ffill') # propagate non-null values forward
raw_df
# raw_df.to_csv('/home/jhan405/cbcv/tft_google_ver4/jianlin-tft/data/preprocessed_data/tft_google/company_0_1000_acq_initaov.csv')
